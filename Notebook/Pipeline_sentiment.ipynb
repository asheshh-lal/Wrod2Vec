# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax
import googleapiclient.discovery
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyCZ9Q_lGbaO9IG2mXoMEVQkHu4zwoP_KEI"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# %% [markdown]
# ### Sentiment analyzer engine

# %%
# Function to fetch comments and perform sentiment analysis
def sentiment_engine(video_id):
    comments = []
    
    # Fetch comments
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100
    )
    response = request.execute()

    while response:
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']
            comments.append([
                comment['authorDisplayName'],
                comment['publishedAt'],
                comment.get('updatedAt', comment['publishedAt']),  # Use publishedAt if updatedAt not present
                comment['likeCount'],
                comment['textDisplay'],
                item['id']  # Add unique comment ID from the API response
            ])

        # Check for next page of comments
        if 'nextPageToken' in response:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=100,
                pageToken=response['nextPageToken']
            )
            response = request.execute()
        else:
            break
    
    # Create DataFrame
    df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text', 'comment_id'])

    def polarity_scores_roberta(text):
        # Encode text and get model output
        encoded_text = tokenizer(text, return_tensors='pt')
        output = model(**encoded_text)
        scores = output[0][0].detach().numpy()
        scores = softmax(scores)
        scores_dict = {
            'roberta_neg': scores[0],
            'roberta_neu': scores[1],
            'roberta_pos': scores[2]
        }
        return scores_dict
    
    res = {}
    
    # Loop through comments and perform sentiment analysis
    for i, row in tqdm(df.iterrows(), total=len(df)):
        try:
            text = row['text']
            comment_id = row['comment_id']  # Use comment ID as a unique key
            
            # Use VADER for sentiment analysis
            vader_result = sia.polarity_scores(text)
            vader_result_rename = {f"vader_{key}": value for key, value in vader_result.items()}
            
            # Use RoBERTa for sentiment analysis
            roberta_result = polarity_scores_roberta(text)
            
            # Combine both results
            both = {**vader_result_rename, **roberta_result}
            res[comment_id] = both
            
        except Exception as e:
            print(f"Error for comment ID {comment_id}: {e}")
    
    # Convert results to DataFrame and merge with original DataFrame
    results_df = pd.DataFrame(res).T.reset_index().rename(columns={'index': 'comment_id'})
    results_df = results_df.merge(df, how='left', on='comment_id')
    
    return results_df

# Fetch comments for a video and perform sentiment analysis
df = sentiment_engine("OzV0tnMahGI")
df.head()
# Out:
# 100%|███████████████████████████████████████████| 18/18 [00:00<00:00, 18.56it/s]
#                    comment_id  vader_neg  vader_neu  vader_pos  \
# 0  Ugzbv4pLF2CIr3WSbjl4AaABAg      0.000      1.000      0.000
# 1  UgyMshI0QDOREfPAq2p4AaABAg      0.000      0.734      0.266
# 2  Ugy3bjrruw6mXrKsYWp4AaABAg      0.474      0.526      0.000
# 3  UgwrZJhufkS2583kOyd4AaABAg      0.178      0.822      0.000
# 4  UgwmXaS9nuDmLm_47Kl4AaABAg      0.000      0.891      0.109
#
#    vader_compound  roberta_neg  roberta_neu  roberta_pos               author  \
# 0          0.0000     0.001087     0.032337     0.966576  @thelightknight4811
# 1          0.4404     0.004731     0.197537     0.797732   @ManuChourasia2029
# 2         -0.4019     0.444784     0.380854     0.174362          @Juiccy_777
# 3         -0.3818     0.463953     0.500175     0.035872         @LeastSlutty
# 4          0.2382     0.281003     0.501992     0.217005         @LeastSlutty
#
#            published_at            updated_at  like_count  \
# 0  2024-10-19T21:11:01Z  2024-10-19T21:11:01Z           0
# 1  2024-10-19T20:58:46Z  2024-10-19T20:58:46Z           0
# 2  2024-10-19T20:55:38Z  2024-10-19T20:55:38Z           2
# 3  2024-10-19T20:51:34Z  2024-10-19T20:51:34Z           0
# 4  2024-10-19T20:50:57Z  2024-10-19T20:50:57Z           1
#
#                                                 text
# 0                   Golazooooo!! Siiuuuuu!!! 😎❤️⚽🔥👍👍
# 1    Furts good goal fro real madrid by kylian mbape
# 2                              The glazing is insane
# 3  Don&#39;t sleep on Milan or Liverpool to upset...
# 4  This is a good team but a CL is NOT GURANTEED....

# %%
comments
# Out:
# [['@MrBeast',
#   '2024-10-12T15:59:31Z',
#   '2024-10-12T15:59:31Z',
#   89298,
#   'The chaos in this video is unreal lol'],
#  ['@Daisy_Bailey',
#   '2024-10-19T20:23:01Z',
#   '2024-10-19T20:23:01Z',
#   0,
#   'STACKED GROUP'],
#  ['@Sandeep_7999',
#   '2024-10-19T20:22:56Z',
#   '2024-10-19T20:22:56Z',
#   0,
#   'Welcome indiA🎉'],
#  ['@YahirRegalado-d6m',
#   '2024-10-19T20:22:23Z',
#   '2024-10-19T20:22:23Z',
#   0,
#   'MR BEAST I FIXED WHEN I MEAN FIXED I MEAN MAKE A NEW ACCOUNT TO WACH YOUR VIDS AND I SUBBED'],
#  ['@SVT_Sonic',
#   '2024-10-19T20:17:23Z',
#   '2024-10-19T20:17:23Z',
#   1,
#   'roblox doors floor 2 vibe'],
#  ['@KaelaBlackfox-t9c',
#   '2024-10-19T20:15:56Z',
#   '2024-10-19T20:15:56Z',
#   0,
#   '10k likes he buys me a now laptop'],
#  ['@SimpleCannon',
#   '2024-10-19T20:14:25Z',
#   '2024-10-19T20:14:25Z',
#   0,
#   'Love the video!'],
#  ['@Mr.Butterscotch-i1k',
#   '2024-10-19T20:05:57Z',
#   '2024-10-19T20:05:57Z',
#   0,
#   'Why does everything look new'],
#  ['@funrider28',
#   '2024-10-19T20:05:32Z',
#   '2024-10-19T20:05:32Z',
#   2,
#   'just put the fries in the bag bro'],
#  ['@gloriaruiz6027',
#   '2024-10-19T20:04:26Z',
#   '2024-10-19T20:04:26Z',
#   0,
#   'Imagínate cantar ahí'],
#  ['@genesismarin5392',
#   '2024-10-19T20:01:29Z',
#   '2024-10-19T20:01:29Z',
#   1,
#   'amooo tus videosss en español obio no se ingles x'],
#  ['@fahmimaulana4977',
#   '2024-10-19T19:55:32Z',
#   '2024-10-19T19:55:32Z',
#   0,
#   'The chaos in this vidio unreal lol'],
#  ['@mulivhuweninefale',
#   '2024-10-19T19:50:18Z',
#   '2024-10-19T19:50:18Z',
#   0,
#   'Pls buy me ps5 you the best YouTuber in the world'],
#  ['@Cartspluscars',
#   '2024-10-19T19:46:32Z',
#   '2024-10-19T19:46:32Z',
#   1,
#   'Omggggg im from romania😂❤😂❤🎉'],
#  ['@RabbiHossin-n4l',
#   '2024-10-19T19:45:26Z',
#   '2024-10-19T19:45:26Z',
#   1,
#   'Im form Bangladesh ❤❤'],
#  ['@anaclaudiavazleal',
#   '2024-10-19T19:35:08Z',
#   '2024-10-19T19:35:08Z',
#   2,
#   'I just ate a burger from Mr beast'],
#  ['@Cezi_LemonPL',
#   '2024-10-19T19:33:11Z',
#   '2024-10-19T19:33:11Z',
#   7,
#   'If MrBeast Did A Daily It Would Be History'],
#  ['@curlyfry14456',
#   '2024-10-19T19:32:42Z',
#   '2024-10-19T19:32:42Z',
#   1,
#   'I never seen speeds face clearer lol'],
#  ['@CesarTemplos',
#   '2024-10-19T19:30:00Z',
#   '2024-10-19T19:30:00Z',
#   1,
#   'Me puedes saludar tengo 9 años me llamo Angel'],
#  ['@SanjayKumar-z4b4j',
#   '2024-10-19T19:28:27Z',
#   '2024-10-19T19:28:27Z',
#   1,
#   'Plz 100days on Ocean'],
#  ['@tiposultangamer3204',
#   '2024-10-19T19:27:48Z',
#   '2024-10-19T19:27:48Z',
#   1,
#   'Mr beast is real hero'],
#  ['@DaniellePhillips-qs3gm',
#   '2024-10-19T19:27:07Z',
#   '2024-10-19T19:27:07Z',
#   1,
#   'I love the new mrbeast lab mutations toys. I got the iconic panther in his toys'],
#  ['@ILYASSEAITKASSI',
#   '2024-10-19T19:24:59Z',
#   '2024-10-19T19:24:59Z',
#   1,
#   'chandler yeeeeeees'],
#  ['@ismi216', '2024-10-19T19:24:34Z', '2024-10-19T19:24:34Z', 0, 'YOO COOL'],
#  ['@deadfishinc.5008',
#   '2024-10-19T19:23:20Z',
#   '2024-10-19T19:23:20Z',
#   2,
#   '@mrBeast idea for a video - real life Geo guesser'],
#  ['@SergeyEats-tx9dz',
#   '2024-10-19T19:21:40Z',
#   '2024-10-19T19:21:40Z',
#   1,
#   'I love your feastables Mr beast its better the toesi rolls I eat it everyday I give a rating of inf its the best chocolate EVER'],
#  ['@arvinprabu2064',
#   '2024-10-19T19:19:21Z',
#   '2024-10-19T19:19:21Z',
#   1,
#   'Bro iam big fan of you i want Tamil language please please please 😢😢😢😢😢😢'],
#  ['@PlushBrothersShow438',
#   '2024-10-19T19:17:49Z',
#   '2024-10-19T19:17:49Z',
#   2,
#   'Video Idea: Giving away 10,000 lunchlys in Africa'],
#  ['@DateToTheFuneral',
#   '2024-10-19T19:17:43Z',
#   '2024-10-19T19:17:43Z',
#   1,
#   'Them boys must be starving'],
#  ['@ShemsieFeta',
#   '2024-10-19T19:16:34Z',
#   '2024-10-19T19:16:34Z',
#   0,
#   'hi best yutuber in the world'],
#  ['@MDRashed_Crush',
#   '2024-10-19T19:15:42Z',
#   '2024-10-19T19:15:42Z',
#   2,
#   'Mrbeast bro I&#39;m back 😊'],
#  ['@AderonkeOgunleye-mj4rk',
#   '2024-10-19T19:13:39Z',
#   '2024-10-19T19:13:39Z',
#   1,
#   'You should do a last to be hipnotized'],
#  ['@Icecreamlover978',
#   '2024-10-19T19:08:21Z',
#   '2024-10-19T19:08:21Z',
#   1,
#   'Mrbeast: today I’m gonna nuke the sun. Chandler: Mrbeast wai- BOOM'],
#  ['@sigmagyatt-l3v',
#   '2024-10-19T19:04:58Z',
#   '2024-10-19T19:04:58Z',
#   7,
#   'Thank god Chandler&#39;s back'],
#  ['@luxurycoachingcentre',
#   '2024-10-19T19:04:14Z',
#   '2024-10-19T19:04:14Z',
#   3,
#   '🙏🙏Thanks for 300+ family ,keep supporting guys ❤❤❤'],
#  ['@chaineej_phood',
#   '2024-10-19T19:04:07Z',
#   '2024-10-19T19:04:07Z',
#   0,
#   'India Wale like ❤️ please'],
#  ['@Rayo9551', '2024-10-19T19:00:28Z', '2024-10-19T19:00:28Z', 1, 'AMAZING!'],
#  ['@nikhilpunase3932',
#   '2024-10-19T19:00:08Z',
#   '2024-10-19T19:00:08Z',
#   0,
#   'Mr beast explore amazon forest pls 🎉'],
#  ['@Robloxfan-b2b',
#   '2024-10-19T18:59:35Z',
#   '2024-10-19T18:59:35Z',
#   1,
#   'I love Mrbeast ❤❤❤❤❤😅'],
#  ['@isab.0299',
#   '2024-10-19T18:56:38Z',
#   '2024-10-19T18:56:38Z',
#   0,
#   'I cant even lie this is the best mrbeast video ever'],
#  ['@BoltLightning79',
#   '2024-10-19T18:55:20Z',
#   '2024-10-19T18:55:20Z',
#   7,
#   'I LIKE MY CHEESE DRIPY BRUHHHH'],
#  ['@Mortal---77769',
#   '2024-10-19T18:54:34Z',
#   '2024-10-19T18:54:34Z',
#   0,
#   'It&#39;s my birthday 🎉🎉🎉🎉🎉'],
#  ['@jackscott6395',
#   '2024-10-19T18:54:11Z',
#   '2024-10-19T18:54:11Z',
#   1,
#   'I really dont like speed'],
#  ['@sambhavingawale8200',
#   '2024-10-19T18:53:52Z',
#   '2024-10-19T18:53:52Z',
#   2,
#   'Challenge:- &quot;for living in lighthouse for 7 days in ocean&quot;❤ 😁'],
#  ['@Yeetusnation',
#   '2024-10-19T18:50:50Z',
#   '2024-10-19T18:50:50Z',
#   5,
#   'Why does everyone think he&#39;s gonna come to yo house 😭🙏'],
#  ['@I_AM_THE_HOLY_COW',
#   '2024-10-19T18:50:45Z',
#   '2024-10-19T18:50:45Z',
#   0,
#   'Hi mr breast'],
#  ['@brittenaycock5594',
#   '2024-10-19T18:48:30Z',
#   '2024-10-19T18:48:30Z',
#   0,
#   'This video is the Best'],
#  ['@MUSAYT-gc2ef',
#   '2024-10-19T18:47:27Z',
#   '2024-10-19T18:47:27Z',
#   0,
#   'Big fan MR BEAST'],
#  ['@hykerbiker-un9oi',
#   '2024-10-19T18:47:06Z',
#   '2024-10-19T18:47:06Z',
#   0,
#   '<a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=140">2:20</a> its not a fear of heights if your under ground its a fear of depth'],
#  ['@Blade-ti5um',
#   '2024-10-19T18:43:58Z',
#   '2024-10-19T18:43:58Z',
#   0,
#   '😮Thats the salt cave Omg i remember how scary all the starse...and im sometimes lick the wall btw its a realy beatiful place so go visit it.'],
#  ['@VLADUSYT',
#   '2024-10-19T18:41:59Z',
#   '2024-10-19T18:41:59Z',
#   0,
#   'Крутое видео'],
#  ['@malabuv4045',
#   '2024-10-19T18:37:22Z',
#   '2024-10-19T18:37:22Z',
#   1,
#   'Plz send me 1million dollar my life will be set😅'],
#  ['@bijaytamang161',
#   '2024-10-19T18:35:18Z',
#   '2024-10-19T18:35:18Z',
#   0,
#   'Support me all guys I m from Nepal 🇳🇵'],
#  ['@luanaventura5498',
#   '2024-10-19T18:30:13Z',
#   '2024-10-19T18:30:13Z',
#   0,
#   'I got ur chocolate today'],
#  ['@acd_gamer169',
#   '2024-10-19T18:29:51Z',
#   '2024-10-19T18:29:51Z',
#   0,
#   'Chandler&#39;s been back he was in the wilderness video'],
#  ['@pretzel-xoxo',
#   '2024-10-19T18:27:52Z',
#   '2024-10-19T18:27:52Z',
#   0,
#   'Hello MrBeast, my name is Pretzel! I’m 15 and live in Dubai, I’m on a journey to be a YouTuber and it would be awesome if I could be in one of your videos, as I’ve been a fan for long. It would really help me and my family out if given the opportunity😊'],
#  ['@ppgaimplais555',
#   '2024-10-19T18:27:33Z',
#   '2024-10-19T18:27:33Z',
#   0,
#   'Aqui los de latam ❤💪'],
#  ['@veronicadecosse4753',
#   '2024-10-19T18:26:44Z',
#   '2024-10-19T18:26:44Z',
#   0,
#   'We got your feastables'],
#  ['@gdhddhhdh',
#   '2024-10-19T18:19:53Z',
#   '2024-10-19T18:19:53Z',
#   0,
#   'מגניב מאוד'],
#  ['@MDKAIUM-u3i',
#   '2024-10-19T18:17:56Z',
#   '2024-10-19T18:17:56Z',
#   0,
#   'Hi Mr. Beast I am your big fan I watch all your videos I am very poor help me a little you help everyone help me a little I am one of your small subscriber'],
#  ['@LuisaFrank-di3cg',
#   '2024-10-19T18:12:09Z',
#   '2024-10-19T18:12:09Z',
#   0,
#   'MrBeast i Love your video&#39;s'],
#  ['@carterfransico',
#   '2024-10-19T18:09:04Z',
#   '2024-10-19T18:09:04Z',
#   2,
#   'Put the prime in the lunch bro 😭🙏'],
#  ['@AbdulrafyButt',
#   '2024-10-19T18:08:46Z',
#   '2024-10-19T18:08:46Z',
#   0,
#   'Mrbeast is cool'],
#  ['@warrior_277',
#   '2024-10-19T18:08:05Z',
#   '2024-10-19T18:08:05Z',
#   0,
#   'Mr beast invite me for some  comping 💔😩'],
#  ['@PashtoBayan-z4b',
#   '2024-10-19T18:06:52Z',
#   '2024-10-19T18:06:52Z',
#   1,
#   'Thanks for 270 subscribers❤❤❤'],
#  ['@ShahabQureshi-hn1uq',
#   '2024-10-19T18:04:47Z',
#   '2024-10-19T18:04:47Z',
#   0,
#   'Love u from Pakistani <a href="http://www.youtube.com/results?search_query=%23zalmi">#zalmi</a> army'],
#  ['@Сергей-л5ы5ъ',
#   '2024-10-19T18:04:21Z',
#   '2024-10-19T18:04:21Z',
#   0,
#   'You are top'],
#  ['@Sfakprova',
#   '2024-10-19T18:03:45Z',
#   '2024-10-19T18:03:45Z',
#   0,
#   'My from in Azerbaijan 🇦🇿 l liked MrBeast Chanel.'],
#  ['@Gojosatoru-ryoikitenkai',
#   '2024-10-19T18:02:51Z',
#   '2024-10-19T18:02:51Z',
#   0,
#   'If I be live in USA I&#39;m gonna be buy festable'],
#  ['@samuelyt0101',
#   '2024-10-19T18:02:27Z',
#   '2024-10-19T18:02:27Z',
#   0,
#   'every time I see it there is a new thumbnail HAHA'],
#  ['@Sohanunr18bd',
#   '2024-10-19T18:00:22Z',
#   '2024-10-19T18:00:22Z',
#   0,
#   'Nice video bro keep it up brother ✨❤️🇧🇩'],
#  ['@MiguelAvalos14',
#   '2024-10-19T18:00:20Z',
#   '2024-10-19T18:00:20Z',
#   0,
#   'I ate a feastables'],
#  ['@Hugothehornet718',
#   '2024-10-19T17:59:53Z',
#   '2024-10-19T17:59:53Z',
#   3,
#   'MrBeast, could you buy me a house, please?'],
#  ['@XSlideisbetter',
#   '2024-10-19T17:59:34Z',
#   '2024-10-19T17:59:34Z',
#   1,
#   'after the incident mrbeast is still one of the best tubers'],
#  ['@Cecilia-d4x1x',
#   '2024-10-19T17:58:06Z',
#   '2024-10-19T17:58:06Z',
#   0,
#   'Hello Mr beast me saludas'],
#  ['@Pandavinay',
#   '2024-10-19T17:56:56Z',
#   '2024-10-19T17:56:56Z',
#   0,
#   'Thanks for 822 Subcriber completed 🙏👍'],
#  ['@kolonistv.9193',
#   '2024-10-19T17:56:50Z',
#   '2024-10-19T17:56:50Z',
#   1,
#   'Amazing amazing'],
#  ['@exequielcarbonero4142',
#   '2024-10-19T17:56:17Z',
#   '2024-10-19T17:56:17Z',
#   0,
#   'Hello mister beast, my son watched the car show. He liked it a lot. He wants you to give him one. ha ha ha.'],
#  ['@assatasidibe1279',
#   '2024-10-19T17:56:05Z',
#   '2024-10-19T17:56:05Z',
#   0,
#   'I subscribe'],
#  ['@vickyrucal1845',
#   '2024-10-19T17:54:06Z',
#   '2024-10-19T17:54:06Z',
#   0,
#   'Me beast probé tus chocolates y me gustaron mucho'],
#  ['@Waizhayat',
#   '2024-10-19T17:53:36Z',
#   '2024-10-19T17:53:36Z',
#   0,
#   'Spend 24 hours in Ocean 🌊'],
#  ['@Annn..z',
#   '2024-10-19T17:50:32Z',
#   '2024-10-19T17:50:32Z',
#   1,
#   'Pero nos vas a dar generadores o no? 🥺'],
#  ['@skwizi_yt',
#   '2024-10-19T17:49:27Z',
#   '2024-10-19T17:49:27Z',
#   1,
#   'я тебя люблю ❤'],
#  ['@magdalenah8601',
#   '2024-10-19T17:48:51Z',
#   '2024-10-19T17:48:51Z',
#   0,
#   'Zjadłem Twoją czekoladę tą gorzką była mega dobra'],
#  ['@carrisablsnchard7663',
#   '2024-10-19T17:44:38Z',
#   '2024-10-19T17:44:38Z',
#   1,
#   'This is so cool 🎉🎉🎉😂'],
#  ['@FofoOm-v6f',
#   '2024-10-19T17:41:04Z',
#   '2024-10-19T17:41:04Z',
#   0,
#   'ادعولي بالتوفيق في حياتي الدراسيه 👍😫🤲❤️'],
#  ['@zurenea',
#   '2024-10-19T17:37:57Z',
#   '2024-10-19T17:37:57Z',
#   0,
#   'this video made me cry soooooo yeah see ya'],
#  ['@razvanluca5142',
#   '2024-10-19T17:36:41Z',
#   '2024-10-19T17:36:41Z',
#   0,
#   'Wow 🤩 🇷🇴'],
#  ['@Cemenidinafik',
#   '2024-10-19T17:32:29Z',
#   '2024-10-19T17:32:29Z',
#   1,
#   'One like= one push-up'],
#  ['@josuemejias9422',
#   '2024-10-19T17:31:13Z',
#   '2024-10-19T17:31:13Z',
#   1,
#   'Que divertido'],
#  ['@BlackGaming-rx9ql',
#   '2024-10-19T17:30:03Z',
#   '2024-10-19T17:30:03Z',
#   0,
#   'For every subscribe that i get from this video I’ll send a reels to my friend❤😂'],
#  ['@MrLimeade',
#   '2024-10-19T17:27:41Z',
#   '2024-10-19T17:27:41Z',
#   0,
#   '<a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=370">6:10</a> who’s drinking San peligrino?'],
#  ['@AliAR-gv3ie',
#   '2024-10-19T17:25:59Z',
#   '2024-10-19T17:25:59Z',
#   0,
#   '\u200fمرحبا مستر بيس أنا بدي مسابقة 💔'],
#  ['@YouRAniMe65000',
#   '2024-10-19T17:22:15Z',
#   '2024-10-19T17:22:15Z',
#   0,
#   '4.56 is the best'],
#  ['@shahzibkhan5267',
#   '2024-10-19T17:18:36Z',
#   '2024-10-19T17:18:36Z',
#   0,
#   'I love WWE and Logan Paul and Mr Beast ❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤'],
#  ['@O-Kaygameplay',
#   '2024-10-19T17:17:45Z',
#   '2024-10-19T17:17:45Z',
#   1,
#   'Omg this video is insane'],
#  ['@rezuan_raj',
#   '2024-10-19T17:16:54Z',
#   '2024-10-19T17:16:54Z',
#   0,
#   'If I could be given some money? I would buy a bird'],
#  ['@AkhananiGceya',
#   '2024-10-19T17:13:49Z',
#   '2024-10-19T17:13:49Z',
#   0,
#   'Akhanani Gceya watching in south africa'],
#  ['@esmeebosma4264',
#   '2024-10-19T17:13:18Z',
#   '2024-10-19T17:13:18Z',
#   2,
#   'I love this vid❤❤❤❤new sub en like😊'],
#  ['@JosueUquillas',
#   '2024-10-19T17:10:45Z',
#   '2024-10-19T17:10:45Z',
#   0,
#   'Mrbeast in Ecuador?? 🇪🇨🇪🇨🇪🇨'],
#  ['@NaharBegum-mf4un',
#   '2024-10-19T17:10:43Z',
#   '2024-10-19T17:10:43Z',
#   1,
#   'Mr beast please 😢😢😢 launch feastibals 🇧🇩 Bangladesh plz plz'],
#  ['@farukkulaz5910',
#   '2024-10-19T17:10:02Z',
#   '2024-10-19T17:10:02Z',
#   0,
#   'WE NEED TO SEE THIS REAL LIFE TANK VS TRAIN!!!'],
#  ['@TheRealBloodHydra',
#   '2024-10-19T17:06:46Z',
#   '2024-10-19T17:06:46Z',
#   0,
#   'I Like my cheese drippy Bruh'],
#  ['@Le_vrai_malicieux',
#   '2024-10-19T17:06:43Z',
#   '2024-10-19T17:06:43Z',
#   0,
#   'Why there is steve at <a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=247">4:07</a> 😂'],
#  ['@ombisht-vp1vh',
#   '2024-10-19T17:05:11Z',
#   '2024-10-19T17:05:11Z',
#   0,
#   'Love from nepal 🇳🇵🇳🇵🇳🇵'],
#  ['@user-touhou',
#   '2024-10-19T17:04:10Z',
#   '2024-10-19T17:04:10Z',
#   1,
#   'Minecraftみたいだ'],
#  ['@HussainiPasha-i7i',
#   '2024-10-19T17:02:30Z',
#   '2024-10-19T17:02:30Z',
#   0,
#   'hello mrbeast can you send feastables pls'],
#  ['@user-Ru3ss5it8t',
#   '2024-10-19T17:00:40Z',
#   '2024-10-19T17:00:40Z',
#   1,
#   'Mr. beast I tried your chocolate'],
#  ['@RASHMI472',
#   '2024-10-19T17:00:25Z',
#   '2024-10-19T17:00:25Z',
#   0,
#   'I am your fan I am Indian'],
#  ['@AmitKumar-yz8le',
#   '2024-10-19T17:00:20Z',
#   '2024-10-19T17:00:20Z',
#   0,
#   'Mr Beast can I come to the sho but I am from India ❤'],
#  ['@Your_Trash-kz1vl',
#   '2024-10-19T16:58:39Z',
#   '2024-10-19T16:58:39Z',
#   0,
#   'Kai’s face while saying it’s fire'],
#  ['@Gamer2039',
#   '2024-10-19T16:57:32Z',
#   '2024-10-19T16:57:32Z',
#   1,
#   'Hey mr beast i,m your biggest fan i make videos to on my channel'],
#  ['@turanazerbaijan386',
#   '2024-10-19T16:55:53Z',
#   '2024-10-19T16:55:53Z',
#   1,
#   'Hello mr beast, l like you, today l eat feastibles and realy the best chocolate in the world. l am from Azerbaijan. Azerbaijani people love you. I love youuuuu❤❤😊.'],
#  ['@YTperrito',
#   '2024-10-19T16:55:25Z',
#   '2024-10-19T16:55:52Z',
#   0,
#   'MRBEAST EN ECUADOR❤'],
#  ['@mehulparmar8089',
#   '2024-10-19T16:54:05Z',
#   '2024-10-19T16:54:05Z',
#   0,
#   'Right Jimmy sir my Help my sir 1..2 million subscribers kardo mele bhi Jimmy sir'],
#  ['@рорка-р8н',
#   '2024-10-19T16:51:29Z',
#   '2024-10-19T16:51:29Z',
#   1,
#   'Привет мисте-бист'],
#  ['@Troll_Shortz_YT',
#   '2024-10-19T16:51:09Z',
#   '2024-10-19T16:51:09Z',
#   0,
#   'superb'],
#  ['@eloannyDemelopereira-n1s',
#   '2024-10-19T16:42:02Z',
#   '2024-10-19T16:42:02Z',
#   0,
#   'O desafio Mr beast a nadar até o fundo do lago'],
#  ['@KabitaGogoi-g9u',
#   '2024-10-19T16:38:42Z',
#   '2024-10-19T16:38:42Z',
#   0,
#   'It&#39;s great ❤'],
#  ['@meh5454',
#   '2024-10-19T16:37:31Z',
#   '2024-10-19T16:37:31Z',
#   0,
#   'Mr beast please donate to branch education. That guy is dope'],
#  ['@GDBHanjela',
#   '2024-10-19T16:36:49Z',
#   '2024-10-19T16:36:49Z',
#   0,
#   'Love you Mr beast ...love from Bangladesh 🇧🇩'],
#  ['@NicoPozo_Gameplays',
#   '2024-10-19T16:36:24Z',
#   '2024-10-19T16:36:24Z',
#   0,
#   'Mr beast explore a scariest forest in the world and survive here 7 days'],
#  ['@ranjnatripathi5031',
#   '2024-10-19T16:33:05Z',
#   '2024-10-19T16:33:05Z',
#   1,
#   'Best boys nightout'],
#  ['@KaiStreamdaily',
#   '2024-10-19T16:32:52Z',
#   '2024-10-19T16:32:52Z',
#   0,
#   '<a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=933">15:33</a> kai&#39;s face bruh😂'],
#  ['@АмираРахимова-и2э',
#   '2024-10-19T16:31:20Z',
#   '2024-10-19T16:31:20Z',
#   0,
#   'I love you ☺️❤️'],
#  ['@EzequielEdgardoOjeda',
#   '2024-10-19T16:31:02Z',
#   '2024-10-19T16:31:02Z',
#   1,
#   'Esperando vídeo de &quot;7 días en el espacio&quot; 😮'],
#  ['@АмираРахимова-и2э',
#   '2024-10-19T16:30:51Z',
#   '2024-10-19T16:30:51Z',
#   0,
#   'Come visit us in Kazakhstan Mr. Beast in Almaty please❤❤❤❤❤'],
#  ['@kemeriahassen3718',
#   '2024-10-19T16:28:41Z',
#   '2024-10-19T16:28:41Z',
#   0,
#   'Ok I subscribed liked watched three times'],
#  ['@Krishnaradhalove-b6k',
#   '2024-10-19T16:24:28Z',
#   '2024-10-19T16:24:28Z',
#   0,
#   'Me aapki har video dekta hu please muje  kush gift milega 😊 please Mr Beast'],
#  ['@solehkurniawan3111',
#   '2024-10-19T16:13:30Z',
#   '2024-10-19T16:13:30Z',
#   0,
#   'Im sorry Mr beast<br>Saya baru bisa menonton video anda karena anak saya baru selesai operasi ❤'],
#  ['@Rp_sgsRp_acc',
#   '2024-10-19T16:13:26Z',
#   '2024-10-19T16:13:26Z',
#   1,
#   '<a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=880">14:40</a>  Yorknew city…<br>HXH REFERENCE⁉️⁉️⁉️'],
#  ['@AnilKumar-vu2fz',
#   '2024-10-19T16:08:30Z',
#   '2024-10-19T16:08:30Z',
#   0,
#   'Mrbeast is american god😊'],
#  ['@PlumPlum-ut2fx',
#   '2024-10-19T16:04:58Z',
#   '2024-10-19T16:04:58Z',
#   0,
#   'Me beast come to Ecuador'],
#  ['@Brothepro1920',
#   '2024-10-19T16:01:30Z',
#   '2024-10-19T16:01:30Z',
#   0,
#   'i’ve been subscribed for almost 5 years and I still haven’t gotten my 🍪'],
#  ['@timatherton8561',
#   '2024-10-19T15:56:42Z',
#   '2024-10-19T15:56:42Z',
#   6,
#   'Proverbs 3:6\r<br> \r<br>in all your ways submit to him, and he will make your paths straight.'],
#  ['@Opokumilton', '2024-10-19T15:51:24Z', '2024-10-19T15:51:24Z', 1, 'Lit'],
#  ['@patvrajpatel4949',
#   '2024-10-19T15:51:03Z',
#   '2024-10-19T15:51:03Z',
#   0,
#   'Op beast❤'],
#  ['@aryanpathak6669',
#   '2024-10-19T15:49:24Z',
#   '2024-10-19T15:49:24Z',
#   1,
#   'seeing chandler just standing behind and just clapping hits hard for some reason'],
#  ['@Iskendarhassan',
#   '2024-10-19T15:48:26Z',
#   '2024-10-19T15:48:26Z',
#   0,
#   'your are great so i like you🥰🥰🥰'],
#  ['@Joseekauanjogos',
#   '2024-10-19T15:47:58Z',
#   '2024-10-19T15:47:58Z',
#   0,
#   'Cr7 ❤'],
#  ['@ANIMEEDITS908',
#   '2024-10-19T15:42:38Z',
#   '2024-10-19T15:42:38Z',
#   3,
#   '1 like = one push-up'],
#  ['@Nyamestales',
#   '2024-10-19T15:41:49Z',
#   '2024-10-19T15:41:49Z',
#   0,
#   'This is massive'],
#  ['@Haadivillagelife',
#   '2024-10-19T15:41:38Z',
#   '2024-10-19T15:41:38Z',
#   0,
#   'Vote for 10k subscribes'],
#  ['@lucerocotillo-s3p',
#   '2024-10-19T15:39:27Z',
#   '2024-10-19T15:39:27Z',
#   0,
#   'Hola chicos, pueden pasar mi cumpleaños conmigo? Por favor sería mi sueño, tengo 6 años y soy su fan'],
#  ['@GladysEncina-gs7zb',
#   '2024-10-19T15:37:58Z',
#   '2024-10-19T15:37:58Z',
#   0,
#   'Eres mí idolo😊❤'],
#  ['@murilosegunt',
#   '2024-10-19T15:35:47Z',
#   '2024-10-19T15:35:47Z',
#   1,
#   'mrbeast add your chocolate to Brazil please!!!'],
#  ['@rignouof',
#   '2024-10-19T15:33:45Z',
#   '2024-10-19T15:33:45Z',
#   0,
#   '(🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f) The best YouTuber is there !<br>(🇫🇷) Le melleur YouTuber est la !'],
#  ['@Joséfggjjkmm',
#   '2024-10-19T15:33:39Z',
#   '2024-10-19T15:33:39Z',
#   0,
#   'Mr beast I heard that you are in Brazil, come here to the city of Sete Lagoas in Minas Gerais'],
#  ['@Satsanka2.0',
#   '2024-10-19T15:31:24Z',
#   '2024-10-19T15:31:24Z',
#   1,
#   '🎉🎉🎉🎉 me like'],
#  ['@jakirkhan-jj3ts',
#   '2024-10-19T15:30:54Z',
#   '2024-10-19T15:30:54Z',
#   0,
#   'I am very poor, my home is Bangladesh. I like to see your bidi too. Sometimes MB is not there so I can&#39;t see I have a wish to meet you.'],
#  ['@asasin1110',
#   '2024-10-19T15:29:20Z',
#   '2024-10-19T15:29:20Z',
#   0,
#   'Я люблю тебя ❤'],
#  ['@SONY-TV6',
#   '2024-10-19T15:28:44Z',
#   '2024-10-19T15:28:44Z',
#   0,
#   'Hi  Mr.Beast'],
#  ['@MirajKhan1-u8v',
#   '2024-10-19T15:28:25Z',
#   '2024-10-19T15:28:25Z',
#   0,
#   'Best journey bro'],
#  ['@javierjuega740',
#   '2024-10-19T15:25:31Z',
#   '2024-10-19T15:25:31Z',
#   0,
#   'Hello😊'],
#  ['@YoanFernández-j7c',
#   '2024-10-19T15:23:17Z',
#   '2024-10-19T15:23:17Z',
#   1,
#   'Quiero jugar en uno de tus juegos'],
#  ['@ArtgallerybyTsm',
#   '2024-10-19T15:22:47Z',
#   '2024-10-19T15:22:47Z',
#   0,
#   'subscribe done,😊 l like your videos...❤❤'],
#  ['@leukemia_warrior',
#   '2024-10-19T15:21:03Z',
#   '2024-10-19T15:21:03Z',
#   0,
#   'Im so lucky if mr.beast is my brother&#39;s'],
#  ['@teresaPerez-m4q',
#   '2024-10-19T15:20:43Z',
#   '2024-10-19T15:20:43Z',
#   0,
#   'The day that this came out, it was my birthday'],
#  ['@AhbabMahbub',
#   '2024-10-19T15:19:58Z',
#   '2024-10-19T15:19:58Z',
#   0,
#   'Nice Beast 😮'],
#  ['@purplepeak5694',
#   '2024-10-19T15:16:32Z',
#   '2024-10-19T15:16:32Z',
#   0,
#   'Super cool😎🙌🏼🙌🏼'],
#  ['@ericwolingames6050',
#   '2024-10-19T15:13:00Z',
#   '2024-10-19T15:13:00Z',
#   0,
#   'Put ishowspeed in more videos and for longer'],
#  ['@bxbster1835',
#   '2024-10-19T15:11:15Z',
#   '2024-10-19T15:11:15Z',
#   0,
#   'I’ve actually been to this place before it was so cool'],
#  ['@anavilchezsantisteban549',
#   '2024-10-19T15:05:08Z',
#   '2024-10-19T15:05:08Z',
#   1,
#   'Hola MrBeast e visto que ayudas a mucha gente y espero que sigas ayudando a muchos mas ojala puedan entender mi idioma ojalá un dia te animes a visitar a peru en especial a mi barrio ventanilla alta que dios te bendifa i te duplique todo lo que ases por los demas i algun dia te animas a venir a peru espero que me ayudes si  asi dios me lo permite conocerte gracias i bendiciones para ti y todos los que andan con tigo'],
#  ['@sojibhd2245',
#   '2024-10-19T15:04:32Z',
#   '2024-10-19T15:04:32Z',
#   0,
#   'Hi i am from Bangladesh.. I don&#39;t know  English well but i watch your video it&#39;s very beautiful and interesting..  i am your big fan..❤❤❤❤❤❤'],
#  ['@AnikGhosh-z3g',
#   '2024-10-19T15:03:40Z',
#   '2024-10-19T15:03:40Z',
#   0,
#   'You 🎉🎉🎉'],
#  ['@سحرابوشقورة',
#   '2024-10-19T15:02:45Z',
#   '2024-10-19T15:02:45Z',
#   0,
#   'مستر بيست افضل يوتيوبر وا ابو الروب'],
#  ['@HIMURPRITHIBI',
#   '2024-10-19T15:01:23Z',
#   '2024-10-19T15:01:23Z',
#   0,
#   'So nice ❤❤❤❤❤❤'],
#  ['@alrishshan7249',
#   '2024-10-19T15:00:55Z',
#   '2024-10-19T15:00:55Z',
#   0,
#   'STOP HATING MRBEAST - REAL HERO OF OUR DAYS'],
#  ['@ВладА4-ш6о',
#   '2024-10-19T14:58:18Z',
#   '2024-10-19T14:58:18Z',
#   5,
#   '&quot;I like myself flying bruh&quot;🗣🗣🗣🗣🗣🔥🔥🔥🔥🔥🔥🔥🔥🔥'],
#  ['@TVKemod21', '2024-10-19T14:57:56Z', '2024-10-19T14:57:56Z', 0, 'Kerennn🎉'],
#  ['@sebasferrario',
#   '2024-10-19T14:53:32Z',
#   '2024-10-19T14:53:32Z',
#   0,
#   'MR BEAST.'],
#  ['@RaffaeleCinus',
#   '2024-10-19T14:49:44Z',
#   '2024-10-19T14:49:44Z',
#   0,
#   'Mr bean&#39;s non ti ho mai visto però sono comunque un fan perché ti avevo visto nell&#39;altro cellulare\U0001fa75\U0001fa77'],
#  ['@maxamedaxmed1158',
#   '2024-10-19T14:49:07Z',
#   '2024-10-19T14:49:07Z',
#   0,
#   'Hello Mr. Beast, I need a computer, I really need it, and I have subscribed to all the tours in the house. Please, if you promise me, I will subscribe to every mobile phone I see, God willing.'],
#  ['@chorkhiboys',
#   '2024-10-19T14:47:07Z',
#   '2024-10-19T14:47:07Z',
#   0,
#   'I want to be a part of ur video  sir'],
#  ['@evandimas5901',
#   '2024-10-19T14:45:02Z',
#   '2024-10-19T14:45:02Z',
#   0,
#   'Keren🎉'],
#  ['@Dr.MoqaddasaMohammadi',
#   '2024-10-19T14:44:02Z',
#   '2024-10-19T14:44:02Z',
#   0,
#   'I like Your Videos 🤩🫀'],
#  ['@seemayadavyadav237',
#   '2024-10-19T14:42:56Z',
#   '2024-10-19T14:42:56Z',
#   0,
#   'Very nice video🎉🎉🎉🎉🎉🎉❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉😊😊😊😊😊😊😊😊'],
#  ['@nadeemAliDelhi',
#   '2024-10-19T14:38:32Z',
#   '2024-10-19T14:38:32Z',
#   0,
#   'Chandler ComeBack 🎉🎉🎉'],
#  ['@Catforevernocap',
#   '2024-10-19T14:36:37Z',
#   '2024-10-19T14:36:37Z',
#   0,
#   '<a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=1229">20:29</a> facts jimmy'],
#  ['@AudreyOdom-w7l',
#   '2024-10-19T14:34:11Z',
#   '2024-10-19T14:34:11Z',
#   0,
#   'CHANDLERRRRRRRRRRRRRRRRR ISSSSSSSSSSSSSSSSS BACKKKKKKKKKKKKK'],
#  ['@shabirali1839',
#   '2024-10-19T14:32:47Z',
#   '2024-10-19T14:32:47Z',
#   0,
#   'Chalanj for india'],
#  ['@An2adg',
#   '2024-10-19T14:31:46Z',
#   '2024-10-19T14:31:46Z',
#   0,
#   '미스터 비스트 한국에 버거집 채인점 만들어 줘요'],
#  ['@joshuamartinez8588',
#   '2024-10-19T14:31:28Z',
#   '2024-10-19T14:31:28Z',
#   2,
#   'All this chaos in one video is crazy'],
#  ['@rajeen-ud6tm',
#   '2024-10-19T14:30:20Z',
#   '2024-10-19T14:30:31Z',
#   0,
#   'Pls pls pls pls pls pls pls pls come to. India and meet me mr beast pls. 😢😢😢😢😢😢❤❤❤❤❤❤❤'],
#  ['@MrKaKago',
#   '2024-10-19T14:29:03Z',
#   '2024-10-19T14:29:03Z',
#   0,
#   'Em muốn làm một cammera cho anh Mrbeat em sẽ cố ngắng đạt được ước mơ mình muốn ✊️'],
#  ['@AMERICAN-l1h',
#   '2024-10-19T14:27:33Z',
#   '2024-10-19T14:27:33Z',
#   0,
#   'I LIKE MY CHEESE DRIPPY BRUHHH <a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=929">15:29</a>'],
#  ['@MyTrip-e9u',
#   '2024-10-19T14:19:47Z',
#   '2024-10-19T14:19:47Z',
#   0,
#   'Really interesting!'],
#  ['@C0C0y3y',
#   '2024-10-19T14:19:34Z',
#   '2024-10-19T14:19:34Z',
#   1,
#   'Ur name is Jimmy'],
#  ['@m.smehedihasan5377',
#   '2024-10-19T14:19:33Z',
#   '2024-10-19T14:19:33Z',
#   0,
#   'Love From  Bangladesh 🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩'],
#  ['@SpyroMcLaughlin',
#   '2024-10-19T14:15:50Z',
#   '2024-10-19T14:15:50Z',
#   2,
#   'I LIKE MY CHEESE DRIPPY BRUH.'],
#  ['@ReginaSaucedo-tk5qo',
#   '2024-10-19T14:13:52Z',
#   '2024-10-19T14:13:52Z',
#   0,
#   'Sin duda uno delos llutuber más famoso además de los mejores bideos😀'],
#  ['@sheyllamora-ochoa8291',
#   '2024-10-19T14:13:24Z',
#   '2024-10-19T14:13:24Z',
#   0,
#   'This video is a classic there&#39;s Kai, Sam and colby 😁😁😁'],
#  ['@hernanmarcelocervantesmald8896',
#   '2024-10-19T14:10:53Z',
#   '2024-10-19T14:10:53Z',
#   0,
#   'Hello mrbeast i&#39;m your fa and know You &#39;re in Ecuador . I&#39;m from  Otavalo. Unfortunadtey i cannot go to Quito please can You come to otavalo. My biggest dream is to meet You.'],
#  ['@YvesSanjai', '2024-10-19T14:09:51Z', '2024-10-19T14:09:51Z', 0, 'Hola 🙂'],
#  ['@boristuapante4306',
#   '2024-10-19T14:09:42Z',
#   '2024-10-19T14:09:42Z',
#   0,
#   'hola Mrbest ven a ecuador porfa🥺'],
#  ['@MaximusAlcarinque',
#   '2024-10-19T14:08:22Z',
#   '2024-10-19T14:08:22Z',
#   0,
#   'This place looks like a prime filming location for any number of movie and series projects. I wonder if any <i>have</i> been filmed there.'],
#  ['@Itslia_123',
#   '2024-10-19T14:01:34Z',
#   '2024-10-19T14:01:34Z',
#   0,
#   'Hi, mrbeast aka Jimmy   me and my cousin have been watching u for a really long time and we wanted to be in one of ur vids   hope we can soon ❤'],
#  ['@Marcelofrancisconi10',
#   '2024-10-19T14:01:07Z',
#   '2024-10-19T14:01:07Z',
#   1,
#   '<a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=395">6:35</a> : RONALDOO!!!'],
#  ['@ตาย่าซาคาเรียน',
#   '2024-10-19T14:01:00Z',
#   '2024-10-19T14:01:00Z',
#   0,
#   'Make it so that your chocolate cake can be enjoyed here too!!!! 😊😊'],
#  ['@TebogoJoseph-oe5jy',
#   '2024-10-19T14:00:40Z',
#   '2024-10-19T14:00:40Z',
#   0,
#   'Can 😊😅I please Mr beast be in one of your video next time 😊'],
#  ['@ตาย่าซาคาเรียน',
#   '2024-10-19T13:59:57Z',
#   '2024-10-19T13:59:57Z',
#   0,
#   'Beast I live in Thailand and they don&#39;t have your chocolate there'],
#  ['@BOB99.shorts',
#   '2024-10-19T13:58:33Z',
#   '2024-10-19T13:58:33Z',
#   6,
#   'thanks for 100 subscribers 🎉🎉'],
#  ['@paakphumjaitv278',
#   '2024-10-19T13:58:16Z',
#   '2024-10-19T13:58:16Z',
#   0,
#   'Mrbeast can you surprise my <br>parents please my parents wedding is on 31th october halloween day pls'],
#  ['@tarahbrown102',
#   '2024-10-19T13:57:44Z',
#   '2024-10-19T13:57:44Z',
#   0,
#   'Let&#39;s go Yankees Karl'],
#  ['@cutecatwow4027',
#   '2024-10-19T13:57:37Z',
#   '2024-10-19T13:57:37Z',
#   1,
#   '1 Like mrbeast will give me 100 dollers'],
#  ['@HasnainZiddi-q7q',
#   '2024-10-19T13:54:36Z',
#   '2024-10-19T13:54:36Z',
#   0,
#   'Assalam alaikum Mr beast'],
#  ['@deannahendriks8076',
#   '2024-10-19T13:52:38Z',
#   '2024-10-19T13:52:38Z',
#   0,
#   'Yo let me play on your team and I will help you Jimmy'],
#  ['@HasnainZiddi-q7q',
#   '2024-10-19T13:52:00Z',
#   '2024-10-19T13:52:00Z',
#   1,
#   'Assalam alaikum  Mr beast'],
#  ['@Ihfu-lwh',
#   '2024-10-19T13:50:10Z',
#   '2024-10-19T13:50:10Z',
#   0,
#   'I’m in România 🎉😂🎉'],
#  ['@zeruhuntilahun4049',
#   '2024-10-19T13:46:33Z',
#   '2024-10-19T13:46:33Z',
#   0,
#   'I wish I can try feastables but I can&#39;t because I am living very far away and they do not sell feastables even if they do it&#39;s just very expensive and my wish is to try feastables and meet you'],
#  ['@amalia1742',
#   '2024-10-19T13:44:45Z',
#   '2024-10-19T13:44:45Z',
#   0,
#   'there is no way mr beast went to romania this is crazy wow'],
#  ['@littlevicecity9075',
#   '2024-10-19T13:41:43Z',
#   '2024-10-19T13:41:43Z',
#   1,
#   'Mr .Beast explore the world and see if their are any double gangers'],
#  ['@ermek831',
#   '2024-10-19T13:41:34Z',
#   '2024-10-19T13:41:34Z',
#   0,
#   'This is the real Mrbeast'],
#  ['@RobinsonKayap',
#   '2024-10-19T13:41:31Z',
#   '2024-10-19T13:41:31Z',
#   0,
#   'Soy de ecuador ❤❤❤'],
#  ['@mak55583',
#   '2024-10-19T13:39:30Z',
#   '2024-10-19T13:39:30Z',
#   3,
#   'You are the best youtuber. I like your videos very much'],
#  ['@NataliGor',
#   '2024-10-19T13:37:55Z',
#   '2024-10-19T13:37:55Z',
#   0,
#   'Мистер бист у тебя самые лучшие видео в мире.ЛЮБЛЮ ТЕБЯ И ТВОИ ВИДЕО'],
#  ['@na_moroze',
#   '2024-10-19T13:35:57Z',
#   '2024-10-19T13:35:57Z',
#   0,
#   'Бист, дай какое нибудь задание в Россию, чтоб можно было выиграть хотя бы самый недорогой мотоцикл😊😊'],
#  ['@Lerpernado1', '2024-10-19T13:34:34Z', '2024-10-19T13:34:34Z', 0, 'yooo😱'],
#  ['@NURSULTANTECHNOLOGY',
#   '2024-10-19T13:34:15Z',
#   '2024-10-19T13:34:15Z',
#   0,
#   'Amazing ❤❤👍👍😂😂'],
#  ['@benjaaaaa512',
#   '2024-10-19T13:32:35Z',
#   '2024-10-19T13:32:35Z',
#   13,
#   'Próximo video: Explorando Atlantis'],
#  ['@bangbara2015',
#   '2024-10-19T13:32:24Z',
#   '2024-10-19T13:32:24Z',
#   3,
#   '<a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=819">13:39</a> I had high expectations for the food.😁'],
#  ['@خضربيشاني-ج8خ',
#   '2024-10-19T13:30:30Z',
#   '2024-10-19T13:30:30Z',
#   0,
#   'Mr. Best, we hope that you will solve the problem of the translator’s voice in Arabic, because we are accustomed to only one voice. Thank you ❤'],
#  ['@bangbara2015',
#   '2024-10-19T13:29:31Z',
#   '2024-10-19T13:29:31Z',
#   0,
#   'Why FEASTABELS not in Indonesia??????'],
#  ['@MuizBalogun-wz2nu',
#   '2024-10-19T13:26:03Z',
#   '2024-10-19T13:26:03Z',
#   0,
#   'I know Mr beast is falling of but is vids are always so fun i lpve this guy please stop attacking bro'],
#  ['@EbbaAndersson-w8c',
#   '2024-10-19T13:23:42Z',
#   '2024-10-19T13:23:42Z',
#   1,
#   'Where is my cookie😮😥'],
#  ['@mukumakawesha9100',
#   '2024-10-19T13:23:01Z',
#   '2024-10-19T13:23:01Z',
#   0,
#   'Nice teddy bear and Chandler'],
#  ['@Tangerina_gtr',
#   '2024-10-19T13:22:54Z',
#   '2024-10-19T13:22:54Z',
#   0,
#   'Oi Mr beast eu sou um brasileiro'],
#  ['@jasminesmith5781',
#   '2024-10-19T13:20:55Z',
#   '2024-10-19T13:20:55Z',
#   1,
#   '<a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=542">9:02</a> Lazarbeam strong asf'],
#  ['@406-n2r',
#   '2024-10-19T13:19:15Z',
#   '2024-10-19T13:19:15Z',
#   0,
#   'Pls Subscribe Please 412'],
#  ['@TOKENE11',
#   '2024-10-19T13:17:42Z',
#   '2024-10-19T13:17:42Z',
#   53,
#   'CHANDLER CAN ACTUALLY MAKE THE SPIRIT GO AWAY BECAUSE GOD PROTECS HIM SO PLEASE ALWAYS BRING HIM IN SURVIVING 🗣️🔥🔥🔥🔥🔥🔥🔥'],
#  ['@RajuAhmed-mo5mw',
#   '2024-10-19T13:15:47Z',
#   '2024-10-19T13:15:47Z',
#   0,
#   '❤️💝'],
#  ['@MarknilsonLinaza-z4x',
#   '2024-10-19T13:12:53Z',
#   '2024-10-19T13:12:53Z',
#   0,
#   'Hi mrbeastI am your biggest fan'],
#  ['@솜-z9o6w',
#   '2024-10-19T13:12:29Z',
#   '2024-10-19T13:12:29Z',
#   0,
#   '와 역사 미스터 비스트 진짜 쩐다'],
#  ['@alejandrailbay8830',
#   '2024-10-19T13:10:55Z',
#   '2024-10-19T13:10:55Z',
#   0,
#   'MrBeast  necesitas ir   a  Africa'],
#  ['@Эльгиза-ф5с',
#   '2024-10-19T13:10:30Z',
#   '2024-10-19T13:10:30Z',
#   0,
#   'Ranaldo is better than Messi Mr Beast'],
#  ['@khatun7498',
#   '2024-10-19T13:10:20Z',
#   '2024-10-19T13:10:20Z',
#   1,
#   'I want 2 lakhs mr beast pleasee😭😭'],
#  ['@joejateejjt3650',
#   '2024-10-19T13:05:07Z',
#   '2024-10-19T13:05:07Z',
#   0,
#   'Se imaginanan a mrbest reforestando los cerros de Perú? Can you imagine mrbest reforesting the hills of Peru?'],
#  ['@adelexus3269',
#   '2024-10-19T13:04:14Z',
#   '2024-10-19T13:04:14Z',
#   1,
#   'can i get feastble pls it is my son who wants it'],
#  ['@kusummothey6318',
#   '2024-10-19T13:02:55Z',
#   '2024-10-19T13:02:55Z',
#   0,
#   'I like my video bahut jyada darawane hai'],
#  ['@MimiOliver-j1c',
#   '2024-10-19T13:01:11Z',
#   '2024-10-19T13:01:11Z',
#   0,
#   'Shout out to Mrs beast'],
#  ['@XiankyleVerano',
#   '2024-10-19T12:59:52Z',
#   '2024-10-19T12:59:52Z',
#   0,
#   'Ay no way chadler😮'],
#  ['@sleepydoggo154',
#   '2024-10-19T12:59:33Z',
#   '2024-10-19T12:59:33Z',
#   6,
#   'Never would thought MrBeast would say &quot;Touch some grass&quot;'],
#  ['@Nbaandnflfan-n7s',
#   '2024-10-19T12:58:09Z',
#   '2024-10-19T12:58:09Z',
#   0,
#   'Can you sign my lunchly box'],
#  ['@AliRaza-qh9uc',
#   '2024-10-19T12:57:57Z',
#   '2024-10-19T12:57:57Z',
#   1,
#   'Mr beast give money me  you are rich good person'],
#  ['@v0zier285',
#   '2024-10-19T12:57:31Z',
#   '2024-10-19T12:57:31Z',
#   0,
#   'I WAS THEREEEEEE'],
#  ['@Marinalda-e9s',
#   '2024-10-19T12:56:38Z',
#   '2024-10-19T12:56:38Z',
#   0,
#   'Mr beast você veio para o Brasil  por que'],
#  ['@Someinterestingknowledge2121',
#   '2024-10-19T12:55:46Z',
#   '2024-10-19T12:55:46Z',
#   0,
#   'Mr beast explore the ocean'],
#  ['@MazZleScars',
#   '2024-10-19T12:52:47Z',
#   '2024-10-19T12:52:47Z',
#   0,
#   'Yorknew city, IS THAT A HUNTERXHUNTER REFERENCE???!!!'],
#  ['@ApurbosaderApurbosader',
#   '2024-10-19T12:48:48Z',
#   '2024-10-19T12:48:48Z',
#   0,
#   'big fan from bangladesh🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩'],
#  ['@AliHamza-h1o3g',
#   '2024-10-19T12:43:59Z',
#   '2024-10-19T12:43:59Z',
#   0,
#   'Hi mr beast iam your big fan'],
#  ['@crazyboyuser-qv5jt5exkuttu2s',
#   '2024-10-19T12:42:38Z',
#   '2024-10-19T12:42:38Z',
#   1,
#   'Today is my birthday but 0 like and subscribers mr beast please help me😢'],
#  ['@AliHamza-h1o3g',
#   '2024-10-19T12:39:46Z',
#   '2024-10-19T12:39:46Z',
#   0,
#   'Hi mr beast im yor big fan'],
#  ['@arizonvaca9452',
#   '2024-10-19T12:37:24Z',
#   '2024-10-19T12:37:24Z',
#   0,
#   'Buenos vídeos hace amigo de nuevo le pido ayudo para mí familia quiero curar a mi madre y las deudas de mi padre por favor 😢'],
#  ['@Afiyablog',
#   '2024-10-19T12:35:10Z',
#   '2024-10-19T12:35:10Z',
#   0,
#   'আমি আপনার ভিডিওতে আসতে চাই আমি বাংলাদেশ থেকে বলছি'],
#  ['@VranamvredaVirana',
#   '2024-10-19T12:31:48Z',
#   '2024-10-19T12:31:48Z',
#   0,
#   'Kamu dari Amerika Serikat dari Indonesia'],
#  ['@stefysima9484',
#   '2024-10-19T12:30:24Z',
#   '2024-10-19T12:30:24Z',
#   0,
#   'I was there whit mi school'],
#  ['@Gh4Gh9BaconSports',
#   '2024-10-19T12:29:14Z',
#   '2024-10-19T12:29:14Z',
#   1,
#   'Mr beast give me ur chocolate I haven&#39;t tried ur chocolate Give me one psls'],
#  ['@MichelleChuñir',
#   '2024-10-19T12:21:39Z',
#   '2024-10-19T12:21:39Z',
#   2,
#   'Hi Mr Beast I am from Equator    I help with My dreams 😅 and espero tu llegada miss You 😅'],
#  ['@MFNgamingpro00001',
#   '2024-10-19T12:21:15Z',
#   '2024-10-19T12:21:15Z',
#   0,
#   'La voz de mr beast en japones es la de naruto JAJAJA'],
#  ['@googlefanefecanyurtfan',
#   '2024-10-19T12:20:04Z',
#   '2024-10-19T12:20:04Z',
#   0,
#   'hello me turkey mrBeast loveee'],
#  ['@kyorujin_',
#   '2024-10-19T12:19:10Z',
#   '2024-10-19T12:19:10Z',
#   1,
#   '<a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=933">15:33</a> FIRE 🔥🔥😐'],
#  ['@andrewmountfield',
#   '2024-10-19T12:15:21Z',
#   '2024-10-19T12:15:21Z',
#   0,
#   'MRBEAST MAKING COME BACK WITH CHADLER.🎉🎉'],
#  ['@Gamingbytaha153',
#   '2024-10-19T12:14:13Z',
#   '2024-10-19T12:14:13Z',
#   2,
#   'Mrbeast I am your big fan please give iPhone 16 pro max please 😢😢😢😢 I need it 😢😢😢❤❤'],
#  ['@linglingcheng4793',
#   '2024-10-19T12:13:55Z',
#   '2024-10-19T12:13:55Z',
#   2,
#   'Mister beast'],
#  ['@ZEBODGAMING-s6s',
#   '2024-10-19T12:11:58Z',
#   '2024-10-19T12:11:58Z',
#   0,
#   'Thanks for 100 subscriber 🎉'],
#  ['@TheMinecrafterofMinecrafts',
#   '2024-10-19T12:11:03Z',
#   '2024-10-19T12:11:03Z',
#   0,
#   'I watched this while eating the Mr Beast box'],
#  ['@ЮлияОтставная-й5р',
#   '2024-10-19T12:08:12Z',
#   '2024-10-19T12:08:12Z',
#   0,
#   'Cool video 👌🔥'],
#  ['@smolPjusk',
#   '2024-10-19T12:03:41Z',
#   '2024-10-19T12:03:41Z',
#   0,
#   'When you have to say the cheese taste like actual cheese, bruh'],
#  ['@EvaXxxx-c1z',
#   '2024-10-19T12:03:22Z',
#   '2024-10-19T12:03:22Z',
#   0,
#   'mrBeast come to Manta Ecuador'],
#  ['@Tigris000',
#   '2024-10-19T12:00:12Z',
#   '2024-10-19T12:00:12Z',
#   0,
#   'more screentime for chandler 🙏🏽'],
#  ['@carlallerena6286',
#   '2024-10-19T11:59:24Z',
#   '2024-10-19T11:59:24Z',
#   3,
#   'Hola mister Beas soy Carla soy de Ecuador quiero participar en uno de tus concursos....soy madre soltera tengo dos hijos... por favor ayudame'],
#  ['@fearwillalwayslose5826',
#   '2024-10-19T11:54:36Z',
#   '2024-10-19T11:54:36Z',
#   7,
#   'Literally love sam and colby'],
#  ['@Reambor',
#   '2024-10-19T11:52:31Z',
#   '2024-10-19T11:52:31Z',
#   1,
#   'ABONE OLDU MrBeast'],
#  ['@Hello1000players',
#   '2024-10-19T11:51:43Z',
#   '2024-10-19T11:51:43Z',
#   0,
#   'Love this typa vids👍'],
#  ['@JawadMushtaqueAhmedGaad',
#   '2024-10-19T11:51:11Z',
#   '2024-10-19T11:51:11Z',
#   3,
#   '😂😂😂😂 <a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=6">0:06</a>'],
#  ['@MihailNiculescu-c9f',
#   '2024-10-19T11:50:34Z',
#   '2024-10-19T11:50:34Z',
#   9,
#   'Adam, my nephew, is a big fan of your show and he visited Salina Turda not long ago, I hope you enjoyed your stay there and come back soon for another show!'],
#  ['@skibidi_ficho',
#   '2024-10-19T11:47:49Z',
#   '2024-10-19T11:47:49Z',
#   0,
#   'Chandler is what i like to see lets gooooo'],
#  ['@MiraZamirowa',
#   '2024-10-19T11:45:52Z',
#   '2024-10-19T11:45:52Z',
#   0,
#   'Мистер бист пожалуйста😫🙏🙏💓 зделай пол ето лава пжжжжжжжжж'],
#  ['@retmisdn',
#   '2024-10-19T11:44:14Z',
#   '2024-10-19T11:44:14Z',
#   1,
#   'MrBeast aku mau ketemu kamu aku nge fans sama kamu dari dulu😢❤😊'],
#  ['@klikbca878',
#   '2024-10-19T11:43:03Z',
#   '2024-10-19T11:43:03Z',
#   0,
#   'I like challenges . Mrbeast'],
#  ['@Unknown-ed7om',
#   '2024-10-19T11:42:32Z',
#   '2024-10-19T11:42:32Z',
#   6,
#   'Hi Mrbeast! <br>I&#39;m a big fan of yours and I love all tour videos and I&#39;ve watched it all. Can I ask something if you can help me to help my mom cause we have a finance problem and I&#39;m currently working rn and all my brother and sister is still studying and I&#39;m the only one who&#39;s working rn. I hope I can meet you in person. I&#39;m only 18y/o in the Philippines. <br>Thank you Mrbeast!'],
#  ['@JustAnime-s9c',
#   '2024-10-19T11:35:26Z',
#   '2024-10-19T11:35:26Z',
#   0,
#   'I&#39;m here to learn from u ,hope that i will make it this time'],
#  ['@veryinteresting203',
#   '2024-10-19T11:35:09Z',
#   '2024-10-19T11:35:09Z',
#   0,
#   '❤❤❤Love you Boss❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤'],
#  ['@ApSp-t6f',
#   '2024-10-19T11:28:22Z',
#   '2024-10-19T11:28:22Z',
#   0,
#   'Bigg fan bro. Iam from Bangladesh'],
#  ['@Genie1-y9l',
#   '2024-10-19T11:22:18Z',
#   '2024-10-19T11:22:18Z',
#   1,
#   'yey chandler is back'],
#  ['@febarquin9267',
#   '2024-10-19T11:17:06Z',
#   '2024-10-19T11:17:06Z',
#   0,
#   'Mrbeast plz do a video wiht cr7'],
#  ['@DANIELGAMER-st2tv',
#   '2024-10-19T11:12:48Z',
#   '2024-10-19T11:12:48Z',
#   1,
#   'We want Hindi videos'],
#  ['@syedimranafzaal433',
#   '2024-10-19T11:11:17Z',
#   '2024-10-19T11:11:17Z',
#   0,
#   'Hey I am your subscriber and I love your chocolate but I am so poor😢'],
#  ['@so.satisfying-u4p',
#   '2024-10-19T11:09:32Z',
#   '2024-10-19T11:09:32Z',
#   0,
#   'Congratulations for your 321M Subscribers 🎉🎉🎉'],
#  ['@High.Graphic.Console.Gaming.4K',
#   '2024-10-19T11:07:49Z',
#   '2024-10-19T11:07:49Z',
#   4,
#   '<a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=514">8:34</a> 😂😂😂😂'],
#  ['@lukephipps4127',
#   '2024-10-19T11:06:41Z',
#   '2024-10-19T11:06:41Z',
#   1,
#   'The way sam and colby split like that was crazy at <a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=248">4:08</a>'],
#  ['@Im-shovo.07',
#   '2024-10-19T11:05:19Z',
#   '2024-10-19T11:05:19Z',
#   0,
#   'Love from Bangladesh. mr beast,, big fan ❤❤❤❤❤❤❤❤❤❤❤❤'],
#  ['@sentinelff786',
#   '2024-10-19T11:03:07Z',
#   '2024-10-19T11:03:26Z',
#   14,
#   'Thanks for the 400 subscribers❤❤'],
#  ['@KarenRamirez-ui2tz',
#   '2024-10-19T11:00:35Z',
#   '2024-10-19T11:00:35Z',
#   3,
#   'MrBeast need to do the biggest Halloween'],
#  ['@khankillerboy5244',
#   '2024-10-19T10:58:55Z',
#   '2024-10-19T10:58:55Z',
#   2,
#   'I am india i want to be in your video want to complete your god task'],
#  ['@hadianurr5452',
#   '2024-10-19T10:57:12Z',
#   '2024-10-19T10:57:12Z',
#   0,
#   'I love Chanel Mr beast❤😂'],
#  ['@jordanxcv',
#   '2024-10-19T10:57:08Z',
#   '2024-10-19T10:57:08Z',
#   0,
#   'yewsssssssssssssssss chandler'],
#  ['@janyurisanmateo2596',
#   '2024-10-19T10:55:48Z',
#   '2024-10-19T10:56:06Z',
#   0,
#   'MrBeast help me I&#39;m from the  Philippines'],
#  ['@ArsalanAlam-t7d',
#   '2024-10-19T10:54:34Z',
#   '2024-10-19T10:57:14Z',
#   2,
#   '👶<br>👕<br>🩳<br><br>His name is John<br><br>He is 0 years old <br>Every likes he gets older'],
#  ['@shiveshsinha705',
#   '2024-10-19T10:53:51Z',
#   '2024-10-19T10:53:51Z',
#   0,
#   'Please release feasteables in india pls pls pls pls pls pls pls pls'],
#  ['@ahmd7er',
#   '2024-10-19T10:51:47Z',
#   '2024-10-19T10:51:47Z',
#   2,
#   'لا اله الا الله وحده لا شريك له له الملك وله الحمد وهو على كل شيء<br>ارجعو إلى الله أن الله غفور رحيم'],
#  ['@Rowdy-420',
#   '2024-10-19T10:48:38Z',
#   '2024-10-19T10:48:38Z',
#   1,
#   'Who is watching from India ❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤ wo like karo ❤❤❤❤❤❤❤❤❤❤ watching from India 🎉🎉🎉🎉🎉🎉🎉🎉🎉'],
#  ['@MuhamadAbubaker-pr8kj',
#   '2024-10-19T10:48:33Z',
#   '2024-10-19T10:48:33Z',
#   0,
#   'Ho sir a big fan from pakistan .......take me in your video plz.........'],
#  ['@Now..official-yt',
#   '2024-10-19T10:47:42Z',
#   '2024-10-19T10:47:42Z',
#   0,
#   'Your support means the world to me! Every like and subscribe keeps me going. Don&#39;t leave me hanging – I need YOU to keep this journey alive!&quot;'],
#  ['@Landon_the_4th',
#   '2024-10-19T10:46:36Z',
#   '2024-10-19T10:46:36Z',
#   1,
#   'I bet everyone that watched this video 20 bucks that jimmy is making a video that he is going on a plane with 0 gravity'],
#  ['@AdityaRoy-c2u',
#   '2024-10-19T10:45:31Z',
#   '2024-10-19T10:45:31Z',
#   5,
#   '100 days challenge dare <a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=1180">19:40</a> ❤'],
#  ['@MarksmanGaming-j1g',
#   '2024-10-19T10:45:21Z',
#   '2024-10-19T10:45:21Z',
#   0,
#   'mrBeast 💖💖💖'],
#  ['@mariamjumat5104',
#   '2024-10-19T10:43:37Z',
#   '2024-10-19T10:43:37Z',
#   0,
#   'YESSSSSS WE GOT SAM&amp;COLBY 🎉 <a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=251">4:11</a>'],
#  ['@bottleofwater-o8f',
#   '2024-10-19T10:36:51Z',
#   '2024-10-19T10:36:51Z',
#   3,
#   'I like my cheese drippy bruh 🗣️🔥🔥'],
#  ['@moviestorybanglafull',
#   '2024-10-19T10:32:35Z',
#   '2024-10-19T10:32:35Z',
#   0,
#   'Mr. Beast for next generation'],
#  ['@HILOTniAMBOY',
#   '2024-10-19T10:28:43Z',
#   '2024-10-19T10:28:43Z',
#   0,
#   '❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️ THE BEST👍👍'],
#  ['@wutmom2158',
#   '2024-10-19T10:22:50Z',
#   '2024-10-19T10:22:50Z',
#   0,
#   'The Best คือคนรวย'],
#  ['@RAZZABOY',
#   '2024-10-19T10:21:27Z',
#   '2024-10-19T10:21:27Z',
#   0,
#   'My bday on 31 of October'],
#  ['@zzhanelle',
#   '2024-10-19T10:17:46Z',
#   '2024-10-19T10:17:46Z',
#   0,
#   'JIMMY DIDN&#39;T TELL ME HE HAD A NEW VID🔥😭'],
#  ['@trainghiemgame94',
#   '2024-10-19T10:17:13Z',
#   '2024-10-19T10:17:13Z',
#   0,
#   'Uầy thú vị đấy chứ <a href="UCkszU2WH9gy1mb0dV-11UJg/KsIfY6LzFoLM6AKanYDQAg"></a>'],
#  ['@MutiaRa-ii1lb',
#   '2024-10-19T10:11:32Z',
#   '2024-10-19T10:11:32Z',
#   1,
#   'Mantap bro'],
#  ['@b.5574',
#   '2024-10-19T10:09:34Z',
#   '2024-10-19T10:09:34Z',
#   0,
#   'I tried your new chocolate 🍫 it is soooooooo good'],
#  ['@RetikRaj-l6b',
#   '2024-10-19T10:02:56Z',
#   '2024-10-19T10:02:56Z',
#   1,
#   'Today is my birthday 🎂 can I get 1k likes 🥹'],
#  ['@NEO_ghost-5',
#   '2024-10-19T10:01:45Z',
#   '2024-10-19T10:01:45Z',
#   0,
#   'Thanks MrBeast<br>👇'],
#  ['@eda.n.b',
#   '2024-10-19T09:57:09Z',
#   '2024-10-19T09:57:09Z',
#   0,
#   'en sevdiğim bölüm bu oldu<a href="UCkszU2WH9gy1mb0dV-11UJg/m8MfY4jbFsWJhL0PyouA2Ak"></a>'],
#  ['@Soumyajit_Giri',
#   '2024-10-19T09:53:30Z',
#   '2024-10-19T09:53:30Z',
#   0,
#   'Bruh, I spent an hour searching how to change the language from Hindi to English'],
#  ['@A3editz-d7i',
#   '2024-10-19T09:51:35Z',
#   '2024-10-19T09:51:35Z',
#   0,
#   'bro i want a pc bro but i cant buy it or ps5'],
#  ['@MC-pk5hq',
#   '2024-10-19T09:47:15Z',
#   '2024-10-19T09:47:15Z',
#   0,
#   'Where is this location?<br>Definitely I will go visit also!<br>Greetings from Australia!'],
#  ['@Kingj-x1n',
#   '2024-10-19T09:42:52Z',
#   '2024-10-19T09:42:52Z',
#   0,
#   'I love your content so much!,Keep going you will get more subscribers❤❤😊'],
#  ['@HamdiJama-v7i',
#   '2024-10-19T09:41:30Z',
#   '2024-10-19T09:41:30Z',
#   0,
#   '<a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=243">4:03</a> 😊'],
#  ['@benpubgbey6734',
#   '2024-10-19T09:41:24Z',
#   '2024-10-19T09:41:24Z',
#   0,
#   'Mr.Beast, please, I have 5000 dollars. We are very poor. I&#39;m serious. Please help me too. I live in a rundown place.'],
#  ['@سفيان-ح3ظ',
#   '2024-10-19T09:37:53Z',
#   '2024-10-19T09:37:53Z',
#   2,
#   'ZAXBIC IS COOL'],
#  ['@NdouNeo',
#   '2024-10-19T09:36:55Z',
#   '2024-10-19T09:36:55Z',
#   0,
#   'Hi Mr beast am your from South Africa ❤'],
#  ['@UnlockEfficiency-o3i',
#   '2024-10-19T09:35:26Z',
#   '2024-10-19T09:35:26Z',
#   0,
#   'make a challenge video to protect like something expensive and keep it save'],
#  ['@Kawasuka1000',
#   '2024-10-19T09:34:56Z',
#   '2024-10-19T09:34:56Z',
#   0,
#   'Romania all the way!!! Really great Country and nice people!!'],
#  ['@TV-yu2bh',
#   '2024-10-19T09:28:36Z',
#   '2024-10-19T09:28:36Z',
#   1,
#   'DOORS 2 IS REAL'],
#  ['@MerceditaPerlada',
#   '2024-10-19T09:24:00Z',
#   '2024-10-19T09:24:00Z',
#   0,
#   'Kai was not playing with them😂😂'],
#  ['@mawialalrinmawia7534',
#   '2024-10-19T09:20:48Z',
#   '2024-10-19T09:20:48Z',
#   0,
#   'Pls let me in your new video pls I&#39;m begging you 😢❤'],
#  ['@Aria1hockey',
#   '2024-10-19T09:19:58Z',
#   '2024-10-19T09:19:58Z',
#   0,
#   'Sam and Colby always looking the best!!'],
#  ['@OoO-k5k3r',
#   '2024-10-19T09:15:46Z',
#   '2024-10-19T09:15:46Z',
#   3,
#   '<a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4">0:00</a> beginning of a master piece'],
#  ['@JOJO大好きマン', '2024-10-19T09:01:54Z', '2024-10-19T09:01:54Z', 0, 'やばい7日間笑'],
#  ['@ZaeemHaider-w2e',
#   '2024-10-19T09:01:15Z',
#   '2024-10-19T09:01:15Z',
#   1,
#   'Mr beast i from pakistan plzzz one chalenge for me pleas'],
#  ['@DianneSakamoto-d4o',
#   '2024-10-19T08:55:28Z',
#   '2024-10-19T08:55:28Z',
#   0,
#   'This is exactly what I needed today.'],
#  ['@MdHanif-tn3up',
#   '2024-10-19T08:53:43Z',
#   '2024-10-19T08:53:43Z',
#   0,
#   'Ami hasib Bangladesh e thaki Ami apnar sob video theke please apni Amar name apnar video te Akbar bolben please 🥺🥺🥺'],
#  ['@Abhishekgaming-yy9jx',
#   '2024-10-19T08:50:26Z',
#   '2024-10-19T08:50:26Z',
#   1,
#   '😮❤❤❤'],
#  ['@hellogacha4589',
#   '2024-10-19T08:48:24Z',
#   '2024-10-19T08:48:24Z',
#   0,
#   'Day 1 of asking Mrbeast to give my family $10,000'],
#  ['@sohagsaha6258', '2024-10-19T08:45:01Z', '2024-10-19T08:45:01Z', 0, '🎉🎉🎉❤'],
#  ['@opnbrownie',
#   '2024-10-19T08:44:00Z',
#   '2024-10-19T08:44:00Z',
#   0,
#   '<a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=244">4:04</a> in the right side of the elevator there&#39;s a Pic of ronald'],
#  ['@ChiragKumar-jf6fn',
#   '2024-10-19T08:42:50Z',
#   '2024-10-19T08:42:50Z',
#   0,
#   'I will stay here for 7 days and make a video of just 20 minutes'],
#  ['@SatyendraKumar-xx8rk',
#   '2024-10-19T08:33:58Z',
#   '2024-10-19T08:33:58Z',
#   0,
#   'Very nice ❤❤'],
#  ['@Nithish-sk9vy',
#   '2024-10-19T08:33:44Z',
#   '2024-10-19T08:33:44Z',
#   0,
#   'Bro actually I am have been seeing ur videos like for r4 years and I wanted to participate in ur activities but the thing is I am an Indian is that possible please bro'],
#  ['@liladharpansania5896',
#   '2024-10-19T08:32:29Z',
#   '2024-10-19T08:32:29Z',
#   0,
#   'I’m watching this videos with eating feastables'],
#  ['@svenlunderstedt992',
#   '2024-10-19T08:31:38Z',
#   '2024-10-19T08:31:38Z',
#   1,
#   'Mein Papa kauft mir nieeee deine Schokolade 😢😢😢😢ich frage ihn die ganze Zeit er sagt aber nein😢😢😢aber trotzdem liebe ich deine neuen Videos ❤❤❤❤🎉🎉🎉'],
#  ['@HuseynYehya',
#   '2024-10-19T08:28:45Z',
#   '2024-10-19T08:28:45Z',
#   0,
#   'Salam men senin hayraninam😊'],
#  ['@HuseynYehya',
#   '2024-10-19T08:28:11Z',
# ...
#  ['@스카이-q2v',
#   '2024-10-18T11:55:10Z',
#   '2024-10-18T11:55:10Z',
#   0,
#   '미스터 비스트 팬이에요😂'],
#  ['@JRADIOCTIVE',
#   '2024-10-18T11:54:45Z',
#   '2024-10-18T11:54:45Z',
#   1,
#   'P.O.V: my Minecraft base'],
#  ['@AshishPal-07',
#   '2024-10-18T11:53:25Z',
#   '2024-10-18T11:53:25Z',
#   1,
#   'Hy mrbeast you help me 😢'],
#  ['@Sonicreem',
#   '2024-10-18T11:51:55Z',
#   '2024-10-18T11:51:55Z',
#   0,
#   'MrBeast is the🎉 Goat'],
#  ['@АльбинаСариева-ы1и',
#   '2024-10-18T11:49:49Z',
#   '2024-10-18T11:49:49Z',
#   0,
#   'Здравствуйте мистер Бист, сними пожалуйста 7 дней закулисье'],
#  ['@smileykavya9225',
#   '2024-10-18T11:48:39Z',
#   '2024-10-18T11:48:39Z',
#   2,
#   'MY BIRTHDAY  BUT  NO  LIKES 😢'],
#  ['@ExpiredAndOldMilk',
#   '2024-10-18T11:48:11Z',
#   '2024-10-18T11:48:11Z',
#   1,
#   '&quot;I like my cheese drippy bruh&quot; 🔥🔥🔥💯'],
#  ['@이주민-i6f', '2024-10-18T11:47:24Z', '2024-10-18T11:47:24Z', 0, '나이스'],
#  ['@surajmatara',
#   '2024-10-18T11:45:13Z',
#   '2024-10-18T11:45:13Z',
#   0,
#   'Bro UR Cristiano is the best 😂🔥'],
#  ['@Chest3000',
#   '2024-10-18T11:43:42Z',
#   '2024-10-18T11:43:42Z',
#   0,
#   'Can you make more videos in Romania please?'],
#  ['@GraceRoji-ee4pm',
#   '2024-10-18T11:40:07Z',
#   '2024-10-18T11:40:07Z',
#   0,
#   'Karl I love you'],
#  ['@ONI_CHAN01',
#   '2024-10-18T11:39:57Z',
#   '2024-10-18T11:39:57Z',
#   0,
#   'ทุกคริปของคุณสนุกมากเลย😊'],
#  ['@Bruninho205',
#   '2024-10-18T11:36:09Z',
#   '2024-10-18T11:36:09Z',
#   0,
#   'É legal eles dublando nosso língua 😂❤❤'],
#  ['@Eera2244',
#   '2024-10-18T11:35:43Z',
#   '2024-10-18T11:35:43Z',
#   0,
#   'Hi I&#39;m your biggest fan from Pakistan please visit Pakistan ❤'],
#  ['@Mainul-yg7eg',
#   '2024-10-18T11:33:21Z',
#   '2024-10-18T11:33:21Z',
#   1,
#   'I want to play any game with @MrBeast'],
#  ['@AndroidGamersnow',
#   '2024-10-18T11:31:57Z',
#   '2024-10-18T11:31:57Z',
#   0,
#   'Can you please help me Mr. beast give me a challange for survival any where in world 😂'],
#  ['@RayoMelvinCardiel',
#   '2024-10-18T11:31:22Z',
#   '2024-10-18T11:31:22Z',
#   1,
#   '❤❤❤❤❤😊'],
#  ['@Peerogaming10',
#   '2024-10-18T11:30:36Z',
#   '2024-10-18T11:30:36Z',
#   1,
#   'Hi mr beast iam your subscriber in India 321M congratulations 🎉'],
#  ['@Стондофф2-ю8р',
#   '2024-10-18T11:26:45Z',
#   '2024-10-18T11:26:45Z',
#   0,
#   '😂😂😂😂 good luck'],
#  ['@ИринаИванова-э4ь9к',
#   '2024-10-18T11:22:06Z',
#   '2024-10-18T11:22:06Z',
#   0,
#   'I love you Mr beast 💗💗'],
#  ['@oooo-or2lv', '2024-10-18T11:19:00Z', '2024-10-18T11:19:00Z', 0, 'Cr7 🤴'],
#  ['@BestErmist',
#   '2024-10-18T11:17:39Z',
#   '2024-10-18T11:17:39Z',
#   0,
#   'MrBeast ❤❤❤'],
#  ['@LelouchC.C',
#   '2024-10-18T11:16:02Z',
#   '2024-10-18T11:16:02Z',
#   0,
#   'Mr beast is the best I like him the most ❤<br>He never fails to make me laugh'],
#  ['@bloxfruitsfan59194',
#   '2024-10-18T11:15:03Z',
#   '2024-10-18T11:15:03Z',
#   0,
#   'MrBeast Please please please a car'],
#  ['@ploxxin2417',
#   '2024-10-18T11:11:12Z',
#   '2024-10-18T11:11:12Z',
#   31,
#   'The underground city is from Romania in a city called Turda. I’m from here and I can tell this was fun to watch for Mr.Beast being in a familiar zone.'],
#  ['@BlessingsZimba-h4z',
#   '2024-10-18T11:09:12Z',
#   '2024-10-18T11:09:12Z',
#   0,
#   'I never knew that it was possible to build a city underground 😅❤'],
#  ['@Sabin.kadariya',
#   '2024-10-18T10:58:19Z',
#   '2024-10-18T10:58:19Z',
#   1,
#   'Thanks for 180 subcribers family please keep supporting guys😢😢🎉🎉❤❤❤❤'],
#  ['@tahaminajerin2188',
#   '2024-10-18T10:56:07Z',
#   '2024-10-18T10:56:07Z',
#   0,
#   '😄'],
#  ['@joannantang1463',
#   '2024-10-18T10:54:40Z',
#   '2024-10-18T10:54:40Z',
#   0,
#   'I love watching this kinds of videos.'],
#  ['@AxD_Official-g6m',
#   '2024-10-18T10:52:55Z',
#   '2024-10-18T10:52:55Z',
#   0,
#   'First time seeing this channel, who here is Mr beast 😅'],
#  ['@アマルフ-o7u',
#   '2024-10-18T10:51:41Z',
#   '2024-10-18T10:51:41Z',
#   2,
#   '久々にチャンドラーが出てくれたのは嬉しいです'],
#  ['@PawsomeMoments-j9v',
#   '2024-10-18T10:42:49Z',
#   '2024-10-18T10:42:49Z',
#   0,
#   'I like sea salt chocolate <a href="https://www.youtube.com/watch?v=bn0Kh9c4Zv4&amp;t=200">3:20</a> 😊😊'],
#  ['@Aman-bj7kr',
#   '2024-10-18T10:41:29Z',
#   '2024-10-18T10:41:29Z',
#   2,
#   'Hii, mr beast can you do a colobration video with me I will take a million dollars 😂😂😂😂😂'],
#  ['@Raffa_show1',
#   '2024-10-18T10:40:08Z',
#   '2024-10-18T10:40:08Z',
#   0,
#   'Me deixe participar do seus vídeos Po favor'],
#  ['@MweekaNakauma-z2s',
#   '2024-10-18T10:35:17Z',
#   '2024-10-18T10:35:17Z',
#   0,
#   'Mr beast is just unreal'],
#  ['@REAL_KJ-f1r',
#   '2024-10-18T10:33:46Z',
#   '2024-10-18T10:33:46Z',
#   0,
#   'Ishowspeed is hereee'],
#  ['@오세희-v8o', '2024-10-18T10:32:34Z', '2024-10-18T10:32:34Z', 0, '한국인도돼요😊'],
#  ['@fuadhossain8084',
#   '2024-10-18T10:30:54Z',
#   '2024-10-18T10:30:54Z',
#   0,
#   'ভাই আপনার ভিডিও আমার অনেক ভালো লাগে আমি আপনার সঙ্গে দেখা করতে চাই'],
#  ['@demoniodefresa',
#   '2024-10-18T10:29:04Z',
#   '2024-10-18T10:29:04Z',
#   1,
#   'Saludos a mrbeast y a los demás me encantaria que estén en mi país me gusta sus videos 😊'],
#  ['@MariaFerencova-li7xn',
#   '2024-10-18T10:27:28Z',
#   '2024-10-18T10:27:28Z',
#   0,
#   'mr beast in japane langue is best it&#39;s like naruto voice'],
#  ['@RameshChauhan-m9k',
#   '2024-10-18T10:27:14Z',
#   '2024-10-18T10:27:14Z',
#   0,
#   'Mrbeast mrbeast mujhe aap ek achcha Samsung ka phone de do'],
#  ['@CalebStacey-b8q',
#   '2024-10-18T10:27:01Z',
#   '2024-10-18T10:27:01Z',
#   21,
#   'The chaos in this vid is the same in my class on a Tuesday'],
#  ['@AfiajannatTaaha',
#   '2024-10-18T10:26:02Z',
#   '2024-10-18T10:26:02Z',
#   0,
#   '😮😮😮🎉'],
#  ['@عبدالوهابالقاعدي-ت7ر',
#   '2024-10-18T10:19:28Z',
#   '2024-10-18T10:19:28Z',
#   0,
#   'I want to win a phone, please😂😢😢😅'],
#  ['@s_yo', '2024-10-18T10:18:04Z', '2024-10-18T10:18:04Z', 0, 'Wow bro'],
#  ['@ArvelReal',
#   '2024-10-18T10:15:51Z',
#   '2024-10-18T10:15:51Z',
#   0,
#   'Msterbis I have subscribed to you pls ask for an iPhone misterbeas you are a good person'],
#  ['@OmorereJoshua-r1p',
#   '2024-10-18T10:11:31Z',
#   '2024-10-18T10:11:31Z',
#   1,
#   'Chandler needs more screen time plz'],
#  ['@Thechelesani',
#   '2024-10-18T10:09:33Z',
#   '2024-10-18T10:09:33Z',
#   0,
#   'Kayl ❤ my favourite😊'],
#  ['@adrianadam8791',
#   '2024-10-18T10:08:06Z',
#   '2024-10-18T10:08:06Z',
#   298,
#   '&quot;I like my video ideas drippy bruh&quot;🗣🗣🔥🔥🔥🔥'],
#  ['@MohiMohiuddin-q9u',
#   '2024-10-18T10:04:45Z',
#   '2024-10-18T10:04:45Z',
#   0,
#   'Wonderful vdo❤'],
#  ['@sudiptamondal7061',
#   '2024-10-18T10:02:59Z',
#   '2024-10-18T10:02:59Z',
#   1,
#   'I am subscribed to Mr Beast but I didn&#39;t get a cookie😢.'],
#  ['@4-ie5of',
#   '2024-10-18T10:00:58Z',
#   '2024-10-18T10:00:58Z',
#   1,
#   '日本のテレビで見たことがあります'],
#  ['@wasikofficial7824',
#   '2024-10-18T10:00:02Z',
#   '2024-10-18T10:00:02Z',
#   0,
#   'futuristic 😮✨'],
#  ['@ShaziaMohammdi',
#   '2024-10-18T09:58:09Z',
#   '2024-10-18T09:58:09Z',
#   0,
#   'wow this vedio is fantastic<br><a href="UCkszU2WH9gy1mb0dV-11UJg/m8MfY4jbFsWJhL0PyouA2Ak"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/m8MfY4jbFsWJhL0PyouA2Ak"></a>'],
#  ['@akshislam2789',
#   '2024-10-18T09:57:58Z',
#   '2024-10-18T09:57:58Z',
#   1,
#   'nice video  Bangladesh 🇧🇩🇧🇩🇧🇩🇧🇩'],
#  ['@MrBes-n4m',
#   '2024-10-18T09:57:55Z',
#   '2024-10-18T09:57:55Z',
#   0,
#   'Please 🥺 subscribe'],
#  ['@alaminalamin-hr6qr',
#   '2024-10-18T09:52:32Z',
#   '2024-10-18T09:52:32Z',
#   0,
#   'mr beast i love u more and more'],
#  ['@ABCclanleader',
#   '2024-10-18T09:52:29Z',
#   '2024-10-18T09:52:29Z',
#   0,
#   'Minecraft aahh cave'],
#  ['@akioplayrbx',
#   '2024-10-18T09:52:14Z',
#   '2024-10-18T09:52:14Z',
#   1,
#   'Like if You&#39;re sigma'],
#  ['@minal4801',
#   '2024-10-18T09:50:42Z',
#   '2024-10-18T09:50:42Z',
#   0,
#   'i want feastable bars 😅 send to india please mr beast'],
#  ['@FardinX-v6h',
#   '2024-10-18T09:50:40Z',
#   '2024-10-18T09:50:40Z',
#   0,
#   'Hey Guy❤ Why You Make Bangla videos'],
#  ['@RiazZada-e1w',
#   '2024-10-18T09:49:33Z',
#   '2024-10-18T09:49:33Z',
#   0,
#   'Pakistan Mr beast Pakistan mein a jao'],
#  ['@meganabigail9506',
#   '2024-10-18T09:47:02Z',
#   '2024-10-18T09:47:02Z',
#   0,
#   'I love ishowspeed and Sam and Colby'],
#  ['@MrHabib1st',
#   '2024-10-18T09:40:59Z',
#   '2024-10-18T09:40:59Z',
#   0,
#   '😂Hi Mr Best lol😂'],
#  ['@RuhiRuhi-c4g',
#   '2024-10-18T09:38:00Z',
#   '2024-10-18T09:39:25Z',
#   0,
#   'Main bahut Garib hun aapke pass job karne ke liye kya karna padega sir please help me 😢😢 aapka har video dekhta hun main 2 salon se dekhta a raha hun 🥺🥺🥺🥺 please koi job dedo sir 😢'],
#  ['@jarifhossain-z2j',
#   '2024-10-18T09:36:16Z',
#   '2024-10-18T09:36:16Z',
#   0,
#   'hi! jimmy'],
#  ['@FarhanaRahman-mf5nw',
#   '2024-10-18T09:33:43Z',
#   '2024-10-18T09:33:43Z',
#   0,
#   'I am your all channel subscribe or  bellnotification ❤❤ I am your big fan ❤❤❤❤❤❤❤❤❤🥰🥰🥰🥰🥰'],
#  ['@NatureLove-u8n',
#   '2024-10-18T09:30:55Z',
#   '2024-10-18T09:30:55Z',
#   0,
#   'Trust me MrBeast Sir'],
#  ['@Omori-IS-LIFE',
#   '2024-10-18T09:27:47Z',
#   '2024-10-18T09:27:47Z',
#   3,
#   '&quot;i like my cheese drippy bruh🔥🔥🗣🗣&quot;'],
#  ['@GopalMondal-jq3rg',
#   '2024-10-18T09:26:36Z',
#   '2024-10-18T09:26:36Z',
#   1,
#   '😮😮😮😮😮😮😮❤❤❤❤❤🎉🎉😊😊😊😮😮😮❤❤❤❤❤❤❤'],
#  ['@SajibIslam-h8m',
#   '2024-10-18T09:25:44Z',
#   '2024-10-18T09:25:44Z',
#   0,
#   'I eat with you😊😊😊'],
#  ['@-veronica-is-amazing',
#   '2024-10-18T09:24:36Z',
#   '2024-10-18T09:24:36Z',
#   5,
#   'I love Sam and colby'],
#  ['@Seafiremsc',
#   '2024-10-18T09:24:27Z',
#   '2024-10-18T09:24:27Z',
#   0,
#   'Sorry, mrbeast, for being mean😢'],
#  ['@NatureLove-u8n',
#   '2024-10-18T09:20:06Z',
#   '2024-10-18T09:20:06Z',
#   0,
#   'Can you help me? Mainly you are a new subscriber. Mainly I am from India. I have to make a caravan for traveling and want to take advice from you. Mainly I am your big fan. <br>MrBeast Sir'],
#  ['@Mostufa098',
#   '2024-10-18T09:13:10Z',
#   '2024-10-18T09:13:10Z',
#   0,
#   'Samanya Nepali 😊'],
#  ['@kondaveetianil2634',
#   '2024-10-18T09:13:07Z',
#   '2024-10-18T09:13:07Z',
#   0,
#   'Any one help his plss help me Mr beast🎉'],
#  ['@sirjbelbase7152',
#   '2024-10-18T09:12:52Z',
#   '2024-10-18T09:12:52Z',
#   0,
#   'Chandler, Lets gooooooooo'],
#  ['@FerlinAzza-d4l',
#   '2024-10-18T09:12:17Z',
#   '2024-10-18T09:12:17Z',
#   0,
#   'Mrbeast sister valens is painting is your❤❤❤<br>Is from indo<br>Hai my name is azza<br>I&#39;m age 10<br>From indo ❤'],
#  ['@tahaamin2233',
#   '2024-10-18T09:11:34Z',
#   '2024-10-18T09:11:34Z',
#   0,
#   'Why are these videos in hindi'],
#  ['@MANJUR-ty3kr',
#   '2024-10-18T09:10:44Z',
#   '2024-10-18T09:10:44Z',
#   0,
#   'Sar Mujhe Bhi Karva Lo Ek challenge'],
#  ['@adityasingh-bc9dn',
#   '2024-10-18T09:06:02Z',
#   '2024-10-18T09:08:05Z',
#   2,
#   'how about this kind of challenge for us high school kids pls read full<br><br>Imagine this: 250 students, 50 schools, and 5 students from each school competing in a challenge inspired by Classroom of the Elite! We’re talking about a next-level test of brains, strategy, physical skill, and teamwork! 💥\r<br>\r<br>Here’s the breakdown:\r<br>\r<br>Intellectual Puzzles &amp; Problem-Solving: Think you can outsmart the competition? Solve complex riddles, academic quizzes, and tricky problems—but watch out, teams can sabotage you with misleading clues! 🧠💡\r<br>\r<br>Physical Endurance &amp; Stamina: Gear up for an intense obstacle course with tricky traps and a survival game where you’ll need to complete tasks while managing limited resources. Who can stay calm under pressure? 🏃\u200d♂🌲\r<br><br>Survival Game: Inspired by the anime’s outdoor test, where students lived in the wilderness and competed for resources, teams can be given limited supplies and must complete tasks (like scavenger hunts or survival tasks) while conserving their resources.<br>\r<br>Psychological &amp; Social Challenges: Trust is key! Can you figure out who’s sabotaging from within your team? Play a mind game like Mafia or Werewolf, where you need to bluff your way to victory. 🤯🕵\u200d♂\r<br>\r<br>Strategic Planning: Manage resources wisely, form alliances, and decide when to betray others. Capture the flag with a twist—temporary alliances will test your social skills and strategic thinking! 🏳🤝\r<br>\r<br>Final Battle: Sacrifice one teammate to take on a solo challenge that could make or break your entire team. It’s all about knowing your strengths and playing smart! 🔥'],
#  ['@PrimeOpusEdits',
#   '2024-10-18T09:05:40Z',
#   '2024-10-18T09:05:40Z',
#   0,
#   'Chandler is the MAN 🗿'],
#  ['@sammyhouse7326',
#   '2024-10-18T09:04:00Z',
#   '2024-10-18T09:04:00Z',
#   0,
#   'U can tell that in this world you have to be someone big to be part of something big! 😅'],
#  ['@zakirMondal-g4m',
#   '2024-10-18T09:02:00Z',
#   '2024-10-18T09:02:00Z',
#   0,
#   'I love  you sir ❤'],
#  ['@Giveawaysdrone',
#   '2024-10-18T09:01:31Z',
#   '2024-10-18T09:01:31Z',
#   0,
#   'Chandler is back  - Yesssssssssss❤❤❤❤❤'],
#  ['@RahulChoudhary-x7n',
#   '2024-10-18T08:57:17Z',
#   '2024-10-18T08:57:17Z',
#   0,
#   'Congratulations MrBeast🎉🎉<br>300 Million subscriber🎉🎉'],
#  ['@MijanurRahman-l7w',
#   '2024-10-18T08:56:38Z',
#   '2024-10-18T08:56:38Z',
#   0,
#   'beast i want to joint you'],
#  ['@dxmanibhai',
#   '2024-10-18T08:56:28Z',
#   '2024-10-18T08:56:28Z',
#   0,
#   'Nic video bhai'],
#  ['@sabir6038',
#   '2024-10-18T08:55:32Z',
#   '2024-10-18T08:55:32Z',
#   0,
#   'I AM INDIAN🇮🇳👳🇮🇳👳'],
#  ['@PecPec718',
#   '2024-10-18T08:52:21Z',
#   '2024-10-18T08:52:21Z',
#   0,
#   'So scary 😅'],
#  ['@AmanThakur-zc1nq',
#   '2024-10-18T08:48:12Z',
#   '2024-10-18T08:48:12Z',
#   0,
#   'Nice vfx'],
#  ['@محمد_20240',
#   '2024-10-18T08:43:36Z',
#   '2024-10-18T08:43:36Z',
#   0,
#   'منو من العراق❤'],
#  ['@surovijahan6370',
#   '2024-10-18T08:43:19Z',
#   '2024-10-18T08:43:19Z',
#   1,
#   'Jimmy come from Bangladesh...your big fan 🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩❤️'],
#  ['@SheikhSadia-i5t',
#   '2024-10-18T08:42:32Z',
#   '2024-10-18T08:42:32Z',
#   0,
#   'You are my favourite  YouTube’s 🖤'],
#  ['@DeerY-e2k',
#   '2024-10-18T08:38:26Z',
#   '2024-10-18T08:38:26Z',
#   0,
#   'Mr beast  is a very kind man, realy'],
#  ['@STRAWNAME',
#   '2024-10-18T08:36:47Z',
#   '2024-10-18T08:36:47Z',
#   0,
#   'It&#39;s crazy 😂😂'],
#  ['@ShahNizam-u6m',
#   '2024-10-18T08:34:55Z',
#   '2024-10-18T08:34:55Z',
#   0,
#   'I&#39;m thinking extreme hide and seek in that place😮'],
#  ['@jangroke5763',
#   '2024-10-18T08:33:57Z',
#   '2024-10-18T08:33:57Z',
#   0,
#   'Jimmy is the 🐐'],
#  ['@jesanovi8341',
#   '2024-10-18T08:33:51Z',
#   '2024-10-18T08:33:51Z',
#   0,
#   'It,s was crazy'],
#  ['@ambrielpossible612',
#   '2024-10-18T08:32:02Z',
#   '2024-10-18T08:32:02Z',
#   0,
#   'My son and daughter&#39;s always watchin your videos.'],
#  ['@Pobbs_4u',
#   '2024-10-18T08:30:45Z',
#   '2024-10-18T08:30:45Z',
#   0,
#   'I like my chocolate salty bruh'],
#  ['@Stolas_the_owl',
#   '2024-10-18T08:29:50Z',
#   '2024-10-18T08:29:50Z',
#   0,
#   'I can&#39;t believe yall came in Romania 😭'],
#  ['@IdeaCenter247',
#   '2024-10-18T08:29:45Z',
#   '2024-10-18T08:29:45Z',
#   0,
#   'I watch all of MrBeast&#39;s videos, and I really enjoy every single one of them. His work and content always carry a sense of positivity that truly impresses me. Personally, I think he&#39;s an exceptional person. He has a kind heart and knows how to inspire others.'],
#  ['@aryalodwal3e629',
#   '2024-10-18T08:28:24Z',
#   '2024-10-18T08:28:24Z',
#   0,
#   'I am your big fan ❤️❤️❤️'],
#  ['@Артм455',
#   '2024-10-18T08:26:33Z',
#   '2024-10-18T08:26:33Z',
#   1,
#   'Мистер бист  приехай в россию'],
#  ['@WenJiang-sr9lk',
#   '2024-10-18T08:25:03Z',
#   '2024-10-18T08:25:03Z',
#   1,
#   'Bro im a kid:('],
#  ['@MONTYGAMINGYT-yf8bm',
#   '2024-10-18T08:24:51Z',
#   '2024-10-18T08:24:51Z',
#   0,
#   '10k likes mrbeast explore the entire sun'],
#  ['@SujanTales',
#   '2024-10-18T08:24:23Z',
#   '2024-10-18T08:24:23Z',
#   0,
#   'I love mrbeast ❤️💓 I&#39;m dr sujan from India 🇮🇳'],
#  ['@ameirestanton7351',
#   '2024-10-18T08:24:21Z',
#   '2024-10-18T08:24:21Z',
#   0,
#   'Dude I can’t get feastables I’m in the pilipines'],
#  ['@HashmiGamer-777',
#   '2024-10-18T08:22:55Z',
#   '2024-10-18T08:22:55Z',
#   0,
#   'mythpat voiceover❤❤'],
#  ['@santoshbhil1604',
#   '2024-10-18T08:22:35Z',
#   '2024-10-18T08:22:35Z',
#   0,
#   'I love you Mr beast I&#39;m big fan'],
#  ['@Riyandini-u5w',
#   '2024-10-18T08:22:19Z',
#   '2024-10-18T08:22:19Z',
#   0,
#   'hi me from indonesia sub 😅😅'],
#  ['@muhammadnadirauni5678',
#   '2024-10-18T08:20:05Z',
#   '2024-10-18T08:20:05Z',
#   1,
#   'MrBest i want Samsung'],
#  ['@CatherineFrost-cl8op',
#   '2024-10-18T08:19:09Z',
#   '2024-10-18T08:19:09Z',
#   0,
#   'make lunchly bigger'],
#  ...]
